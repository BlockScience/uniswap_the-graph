# %% [markdown]
# # The Graph-Uniswap V2 exploration

# %%
import requests
import json
import pandas as pd
from tqdm import tqdm
pd.set_option('display.precision',20)

# %%
# check which tokens are being traded
token_query = """query{
  tokens (first: 100, skip: 100){
    id,
    symbol,
    txCount
  }
}"""

# %%
uniswap_url = 'https://api.thegraph.com/subgraphs/name/uniswap/uniswap-v2'
token_list = []
for i in tqdm(range(0, 5500, 100)):
    try:
        token_query = """query{
          tokens (first: 100, skip: %d){
        id,
        symbol,
        txCount
          }
        }""" % (i)
        token_req = requests.post(uniswap_url, json={'query': token_query})
        token_data = json.loads(token_req.text)
        token_list += token_data['data']['tokens']
    except:
        pass
# Out:
# 100%|██████████| 55/55 [00:21<00:00,  2.52it/s]

# %%
token_data = json.loads(token_req.text)

# %%
token_list
# Out:
# [{'id': '0x00000000000045166c45af0fc6e4cf31d9e14b9a',
#   'symbol': 'BID',
#   'txCount': '907'},
#  {'id': '0x0000000000004946c0e9f43f4dee607b0ef1fa1c',
#   'symbol': 'CHI',
#   'txCount': '61725'},
#  {'id': '0x000000000000d0151e748d25b766e77efe2a6c83',
#   'symbol': 'XDEX',
#   'txCount': '3245'},
#  {'id': '0x0000000000085d4780b73119b644ae5ecd22b376',
#   'symbol': 'TUSD',
#   'txCount': '37134'},
#  {'id': '0x0000000000095413afc295d19edeb1ad7b71c952',
#   'symbol': 'LON',
#   'txCount': '43693'},
#  {'id': '0x00000000001876eb1444c986fd502e618c587430',
#   'symbol': 'dDai',
#   'txCount': '1'},
#  {'id': '0x0000000000b3f879cb30fe243b4dfee438691c04',
#   'symbol': 'GST2',
#   'txCount': '8813'},
#  {'id': '0x0000000000c75051bba15a706758bd521644c19d',
#   'symbol': 'XGME',
#   'txCount': '65'},
#  {'id': '0x00000000441378008ea67f4284a57932b1c000a5',
#   'symbol': 'TGBP',
#   'txCount': '560'},
#  {'id': '0x00000100f2a2bd000715001920eb70d229700085',
#   'symbol': 'TCAD',
#   'txCount': '128'},
#  {'id': '0x00006100f7090010005f1bd7ae6122c3c2cf0090',
#   'symbol': 'TAUD',
#   'txCount': '169'},
#  {'id': '0x0000852600ceb001e08e00bc008be620d60031f2',
#   'symbol': 'THKD',
#   'txCount': '319'},
#  {'id': '0x0000a1c00009a619684135b824ba02f7fbf3a572',
#   'symbol': 'ALCH',
#   'txCount': '4544'},
#  {'id': '0x0000a5050a8036d29afa9bf36546efe225ed51e9',
#   'symbol': 'WSF',
#   'txCount': '56'},
#  {'id': '0x000387483308752ee8a478d1939002aa6da18461',
#   'symbol': 'DEM20',
#   'txCount': '36'},
#  {'id': '0x0006abbe90dc7e63fb9161969a5c9ee7ad62e901',
#   'symbol': 'IG-11',
#   'txCount': '253'},
#  {'id': '0x0008a6744793ccaabf5df45ae53e3890352ed961',
#   'symbol': 'CCC',
#   'txCount': '2'},
#  {'id': '0x000a909fb5f90fd6c5406b6ea68158d1392a69c7',
#   'symbol': 'TANK',
#   'txCount': '211'},
#  {'id': '0x000b05b50ecb62ee8b6b2d16c3c1185637ca967e',
#   'symbol': 'FEL',
#   'txCount': '10'},
#  {'id': '0x000e8a19eb6e5882de57e817ecf00fa7fa595b16',
#   'symbol': '  PEARL',
#   'txCount': '7'},
#  {'id': '0x0018e66a1dea81fdd767cbb15673119b034b5cf2',
#   'symbol': 'BNSG',
#   'txCount': '272'},
#  {'id': '0x0019a8860fa173d40831d03dd2e668cfc6a59f35',
#   'symbol': 'ESS',
#   'txCount': '4'},
#  {'id': '0x001b12512b51d8e1f954b47c33e0d738318ffc49',
#   'symbol': 'XSHU',
#   'txCount': '23'},
#  {'id': '0x001bc17076d6264492287ac6ba04a42b7960e59e',
#   'symbol': 'BIRD',
#   'txCount': '11'},
#  {'id': '0x001e1bd03e2cb28a4958db5b71b4caaa381a59f1',
#   'symbol': 'MONKEY',
#   'txCount': '3'},
#  {'id': '0x001ed91e7b2ebe579e3d051fd32130087324b13d',
#   'symbol': 'core',
#   'txCount': '10'},
#  {'id': '0x001f0aa5da15585e5b2305dbab2bac425ea71007',
#   'symbol': 'IPSX',
#   'txCount': '46'},
#  {'id': '0x001f265fcf3dc40f373a44bac600c6cb1eea64bd',
#   'symbol': 'MMC',
#   'txCount': '14'},
#  {'id': '0x0020c438f90e635ea0f3d05ba30db61c6812e256',
#   'symbol': 'TOMI',
#   'txCount': '3'},
#  {'id': '0x0020d80229877b495d2bf3269a4c13f6f1e1b9d3',
#   'symbol': 'DEXM',
#   'txCount': '13358'},
#  {'id': '0x00258a960a194acc5eadbede92fd58c73de4ac93',
#   'symbol': 'YCF',
#   'txCount': '13'},
#  {'id': '0x0026b6fe537e0a4733e1223132a39fae91407827',
#   'symbol': 'DEFI',
#   'txCount': '141'},
#  {'id': '0x00294f75ad3fbd51f0359b82fc7fbfa18e83584a',
#   'symbol': 'SOUP',
#   'txCount': '10'},
#  {'id': '0x002eded60c6faf61b5dcfa8fb5832a388fc38523',
#   'symbol': 'DOGES',
#   'txCount': '155'},
#  {'id': '0x002ef27dee7a7d74ba59671385c51aa3d561d228',
#   'symbol': 'SCRT',
#   'txCount': '74'},
#  {'id': '0x0031b46fb108e79047498f9bd0751a09dfbaa84f',
#   'symbol': 'XCM',
#   'txCount': '10'},
#  {'id': '0x0032983c554f08fd21675dbc83e323cc7cf2c3fe',
#   'symbol': 'Versus',
#   'txCount': '511'},
#  {'id': '0x0032c50732e6365e751abd788bb9147730d315e6',
#   'symbol': 'UDS2020',
#   'txCount': '0'},
#  {'id': '0x003b6561606c439a14909f4b0a29fc452209d540',
#   'symbol': 'YFIO',
#   'txCount': '14'},
#  {'id': '0x003da78deb9dd263d46bf992da4fa255aa9766fc',
#   'symbol': 'CBC',
#   'txCount': '9'},
#  {'id': '0x003daa5b2dabd7f4512f1855dffbb0080682102c',
#   'symbol': 'YPLT',
#   'txCount': '9'},
#  {'id': '0x003e0af2916e598fa5ea5cb2da4edfda9aed9fde',
#   'symbol': 'BSD',
#   'txCount': '51'},
#  {'id': '0x003fb03e851f435e79066dcf652d84b53f1d66c5',
#   'symbol': 'GNB',
#   'txCount': '113'},
#  {'id': '0x00440cd01642fe9b6daf973001536ebdc28a1de1',
#   'symbol': 'NPEX',
#   'txCount': '2'},
#  {'id': '0x0044eaf9c6b03216ea829b74069bcdc1fa126f41',
#   'symbol': 'AVAX',
#   'txCount': '19'},
#  {'id': '0x0048bac562f7745916c45c5f2753a37977fa963f',
#   'symbol': 'ABASE',
#   'txCount': '15'},
#  {'id': '0x0048dc5ace0a2ed26e3aaa0f573cc4e82ab262fb',
#   'symbol': 'EHC',
#   'txCount': '2'},
#  {'id': '0x004a9488c761334cec04d5cdcd4cde9bf57404bf',
#   'symbol': 'CHABR',
#   'txCount': '13'},
#  {'id': '0x004bf5bae20b84a261f96d4e5db563fef0fd531b',
#   'symbol': 'FTCH',
#   'txCount': '14'},
#  {'id': '0x004e53aed4a41981f61fff1a227635bdeb5a0d65',
#   'symbol': 'ZMP',
#   'txCount': '11'},
#  {'id': '0x005039bdddcdb9d8417d434e3241620bb5aefa87',
#   'symbol': 'DWE',
#   'txCount': '34'},
#  {'id': '0x00513934474eee5f666edaad418ce9c1e2f48011',
#   'symbol': 'EMD',
#   'txCount': '175'},
#  {'id': '0x00533205a4001cd396789b5c873b4a2f2c83d5fc',
#   'symbol': 'DXXXCX',
#   'txCount': '14'},
#  {'id': '0x0053896672cdbc89df4e15508d95bd6c12800989',
#   'symbol': 'KUBER',
#   'txCount': '7'},
#  {'id': '0x00559b8719ef09ff7ceda48992f3f4edb55a349b',
#   'symbol': 'GLIZZ',
#   'txCount': '19'},
#  {'id': '0x005734a34882113c2fcfa5bfc1ce477d11af3260',
#   'symbol': 'PAJ',
#   'txCount': '28'},
#  {'id': '0x0058de04623950a3c2aa150b58e4fe65a3161487',
#   'symbol': 'pDoge',
#   'txCount': '31'},
#  {'id': '0x0058eeba118d491fd18abed9829c0b9556ce24ba',
#   'symbol': 'GEN',
#   'txCount': '51'},
#  {'id': '0x005ee8ba262732e42d071704e071fc036c4de284',
#   'symbol': 'MAR',
#   'txCount': '21'},
#  {'id': '0x00619ea5a1cc9e9ef8d02a4ebe9f69b3bc387098',
#   'symbol': 'BTHIBA',
#   'txCount': '35'},
#  {'id': '0x00648352116ee86b53903c9a8fab14c718dce8c7',
#   'symbol': 'OLX',
#   'txCount': '73'},
#  {'id': '0x006699d34aa3013605d468d2755a2fe59a16b12b',
#   'symbol': 'Zild',
#   'txCount': '3520'},
#  {'id': '0x00680c756658c8361260d3b46375f2142bf52795',
#   'symbol': 'TRB v2',
#   'txCount': '2'},
#  {'id': '0x00685209b97d9b51c38b0f2d007bc37758df45d3',
#   'symbol': 'DRA',
#   'txCount': '10'},
#  {'id': '0x0068e1ac8654ec6f67baf67c27f9af317d334a35',
#   'symbol': 'AAC',
#   'txCount': '2'},
#  {'id': '0x006a6a9531954d4377fd2371b4c9c416400d6fae',
#   'symbol': 'SWT',
#   'txCount': '97'},
#  {'id': '0x006a825bb45e38a58a2d5ecbf9e2353a8f3a859f',
#   'symbol': 'YFFFF',
#   'txCount': '32'},
#  {'id': '0x006c7b41fafe9d8e105b90bb5e035c4314f62676',
#   'symbol': 'RFI',
#   'txCount': '38'},
#  {'id': '0x006e75c5afc39921b650b7f360e3e70c5429086f',
#   'symbol': 'VGMT',
#   'txCount': '27'},
#  {'id': '0x0070185cd1d9b107509c0fcf319d38e90680fbb8',
#   'symbol': 'CLIQ',
#   'txCount': '4'},
#  {'id': '0x00708207b9ec5c40ad2bd7d0ff7f0aa172a19e7a',
#   'symbol': 'UT',
#   'txCount': '11'},
#  {'id': '0x0070c6594d9632f927eba5f95bf413d9115fbe9e',
#   'symbol': 'NEB',
#   'txCount': '3301'},
#  {'id': '0x0074709700fadb2ed6a9763461cab393e0753c90',
#   'symbol': 'GigaFiC',
#   'txCount': '30'},
#  {'id': '0x00767fa00d142f9c410de48dcb537c59e7cc2c28',
#   'symbol': 'BFLY',
#   'txCount': '23'},
#  {'id': '0x0076d46eeabc1f9cec363c79b1f8424f0e7c453c',
#   'symbol': 'DOGES',
#   'txCount': '29'},
#  {'id': '0x007a64f9d0b97c21a1c4507d2d5e4828d9390852',
#   'symbol': 'CDC',
#   'txCount': '8'},
#  {'id': '0x0080cfc1b3177a45a4459b2e85cd202c26b37eb9',
#   'symbol': 'DOBIT',
#   'txCount': '2'},
#  {'id': '0x0080d4b7be95b550a69e8789340baa38da771743',
#   'symbol': 'USX',
#   'txCount': '1'},
#  {'id': '0x008284d2293b1295b6a4f4a39a6a2f5aac715930',
#   'symbol': 'SEXYF',
#   'txCount': '2'},
#  {'id': '0x0082ea5a7d3f7a117945cf7174335862b98132e7',
#   'symbol': 'ART',
#   'txCount': '10'},
#  {'id': '0x0087feb9d0884720347fdd360a51dbff799b3d1e',
#   'symbol': '1MIL',
#   'txCount': '22'},
#  {'id': '0x008b5dce54ab95d3226c42ef427fed2ff7a82aa4',
#   'symbol': 'DFAL',
#   'txCount': '52'},
#  {'id': '0x008f1d94ad209a5cc9439ba515f619f1d015412e',
#   'symbol': 'OTD',
#   'txCount': '27'},
#  {'id': '0x008f35d034a7055c24041609f8c04e51e97c1481',
#   'symbol': 'AUDIU',
#   'txCount': '10'},
#  {'id': '0x008fba7f46446014fd458c47f1cc35f2f7c020b7',
#   'symbol': 'COVi',
#   'txCount': '11'},
#  {'id': '0x008ff94ec11bbfc4fa5f41008f063dd6b7547d39',
#   'symbol': 'UH3XBOMB',
#   'txCount': '18'},
#  {'id': '0x0091d7884c375c148e5cd7607f463a5da2990b32',
#   'symbol': 'LTCu',
#   'txCount': '4'},
#  {'id': '0x00920fc4b6698e5c7f144c6ee16cb3ed9d238142',
#   'symbol': 'XRN',
#   'txCount': '6'},
#  {'id': '0x00930c19e823df58b6150282e3ef641b30a40ef8',
#   'symbol': 'DUEL',
#   'txCount': '3'},
#  {'id': '0x009631f3cb11a9af2e2f0186e698a2bc976d86eb',
#   'symbol': 'ETHD',
#   'txCount': '5'},
#  {'id': '0x009abded37f477fcbad8f102bccb1675c92b09f6',
#   'symbol': 'SUN',
#   'txCount': '65'},
#  {'id': '0x009eb33b1d62991874f7049e688fbe5f53700e3c',
#   'symbol': 'Alphabet',
#   'txCount': '28'},
#  {'id': '0x009ff208cbac865d59fa743aa4207197c33ac984',
#   'symbol': 'MEV',
#   'txCount': '6'},
#  {'id': '0x00a0360c9ee3860e4438cb0c11968b7263dbb1e7',
#   'symbol': 'PCF',
#   'txCount': '17'},
#  {'id': '0x00a542f9ef8464a6b64663d6ca0ca5a1b4376194',
#   'symbol': 'DTF',
#   'txCount': '5'},
#  {'id': '0x00a66189143279b6db9b77294688f47959f37642',
#   'symbol': 'coreDAI',
#   'txCount': '600'},
#  {'id': '0x00a6d3e564f82acecb445f57138c6c14f0d05ccb',
#   'symbol': 'MECH',
#   'txCount': '115'},
#  {'id': '0x00a884e8d8a8fd52f11ce7acaa55294e2c01e7c3',
#   'symbol': 'SHAM',
#   'txCount': '5'},
#  {'id': '0x00a8b738e453ffd858a7edf03bccfe20412f0eb0',
#   'symbol': 'ALBT',
#   'txCount': '108506'},
#  {'id': '0x00a9a70b94fc1f97141f99d90a3471cf49edadd9',
#   'symbol': 'DBI',
#   'txCount': '11'},
#  {'id': '0x00ae008e48a7ff9e32f36f4731236dc96ff93f1f',
#   'symbol': 'BOI',
#   'txCount': '11'},
#  {'id': '0x00afa7e8820831d9f4169ecfbb66576eb0a37197',
#   'symbol': 'D3N0',
#   'txCount': '59'},
#  {'id': '0x00b0a5f9af10e9ff334cec2875a4a0cbc1003ffd',
#   'symbol': 'LIBRA',
#   'txCount': '46'},
#  {'id': '0x00b10982010c28e093209fbc2c09582c780c4504',
#   'symbol': 'BULL',
#   'txCount': '17'},
#  {'id': '0x00b1881c7d2f34363e455c27df9fb314e47b9a4a',
#   'symbol': 'YZF',
#   'txCount': '39'},
#  {'id': '0x00b18c52b72ef1b6011962ca263c18c451bfbc9a',
#   'symbol': 'GIX',
#   'txCount': '8'},
#  {'id': '0x00b7db6b4431e345eee5cc23d21e8dbc1d5cada3',
#   'symbol': 'CTC',
#   'txCount': '51'},
#  {'id': '0x00b955b7fe9766418382b41c40bfabfcbd0f5751',
#   'symbol': 'VBASE',
#   'txCount': '302'},
#  {'id': '0x00b9b760963e2d8ba069453c2a10907a966ca306',
#   'symbol': 'SPI',
#   'txCount': '50'},
#  {'id': '0x00bc080c599d187a68e0c087b686e7870ac7dc2a',
#   'symbol': 'Ghost',
#   'txCount': '10'},
#  {'id': '0x00bc3018d474990960145b7dfb10329464434cdc',
#   'symbol': 'PNT',
#   'txCount': '14'},
#  {'id': '0x00bc4bcd7308bef72d039003cb59492a20835801',
#   'symbol': 'DAFS',
#   'txCount': '18'},
#  {'id': '0x00c00e7c07b4b455015ee03dde668983dbcb5dd9',
#   'symbol': 'ASCAM',
#   'txCount': '5'},
#  {'id': '0x00c14a124b7c096866ea05dfa9ab8aeab1ccf225',
#   'symbol': 'YFFV',
#   'txCount': '254'},
#  {'id': '0x00c300c5ae4734abc8b19b71bb2f5f03e829dd4c',
#   'symbol': 'EG',
#   'txCount': '13'},
#  {'id': '0x00c3a4ea499cf8a68f26ec78fad0bd2be28c2769',
#   'symbol': 'YZK',
#   'txCount': '5'},
#  {'id': '0x00c49fda8dac06b2fe695f2c594d0d30b5eaf65c',
#   'symbol': 'BAPE',
#   'txCount': '11'},
#  {'id': '0x00c75a83cb5150f50ecd7559a4c82ec42b791934',
#   'symbol': 'YVF',
#   'txCount': '33'},
#  {'id': '0x00c83aecc790e8a4453e5dd3b0b4b3680501a7a7',
#   'symbol': 'SKL',
#   'txCount': '20608'},
#  {'id': '0x00c90165db6ebc006b2ddb695e8c0e28506adc28',
#   'symbol': 'test',
#   'txCount': '2'},
#  {'id': '0x00c952823ef755cc6c9611aff0548605c8cde649',
#   'symbol': 'ZTK',
#   'txCount': '19'},
#  {'id': '0x00cb166e39a77a693146a13536f72f5bef689511',
#   'symbol': 'XTF.WWWBLU',
#   'txCount': '3'},
#  {'id': '0x00ce26f43cc3dfe0a899ee011761066cea8d2179',
#   'symbol': 'XROOT',
#   'txCount': '38'},
#  {'id': '0x00d1793d7c3aae506257ba985b34c76aaf642557',
#   'symbol': 'TACO',
#   'txCount': '15369'},
#  {'id': '0x00d2f4abb3166aabb8e5d8d43e6d571f9a455621',
#   'symbol': 'MUST',
#   'txCount': '27'},
#  {'id': '0x00d78e74c866b2056ba17afbbb175f76e06db3a7',
#   'symbol': 'USWAP',
#   'txCount': '48'},
#  {'id': '0x00d8308b7ac4bc8332a7d006eca41c948ddebf40',
#   'symbol': 'YFIN',
#   'txCount': '9'},
#  {'id': '0x00d9bee3133648a1eebefdc06dc9c7c6be22f8fc',
#   'symbol': 'LTH',
#   'txCount': '22'},
#  {'id': '0x00dd301d59e4248e991db96a747a3c062888a1fb',
#   'symbol': 'DDM',
#   'txCount': '7'},
#  {'id': '0x00de12bb823e771ddf539d11b54517b133deed18',
#   'symbol': 'HDC',
#   'txCount': '10'},
#  {'id': '0x00dee61d313ea7e3631a81192f3e63a511507815',
#   'symbol': 'FSW',
#   'txCount': '3'},
#  {'id': '0x00e150d741eda1d49d341189cae4c08a73a49c95',
#   'symbol': 'INF',
#   'txCount': '27'},
#  {'id': '0x00e2d42bc7b59a313253ab548f8415540280a270',
#   'symbol': 'CHARM',
#   'txCount': '2'},
#  {'id': '0x00e84b77ec5e9b7c696fe1d4657b322315cc7e2e',
#   'symbol': 'JYT',
#   'txCount': '9'},
#  {'id': '0x00ebca566888012bcca521cba2c3291ddd28b958',
#   'symbol': 'YFSG',
#   'txCount': '9'},
#  {'id': '0x00eca744d071cc3d497a522cc8b1aa6cf2562528',
#   'symbol': 'TRADE',
#   'txCount': '10'},
#  {'id': '0x00ee41dcc47045a85bcf7784264f23a6f8bad35c',
#   'symbol': 'PITCH',
#   'txCount': '1'},
#  {'id': '0x00f03ae7d297a73f4b18b0a83e2b7c6881b989ea',
#   'symbol': 'FOR',
#   'txCount': '30'},
#  {'id': '0x00f2447869ccae56abc8464857a9b5b14c21a7d9',
#   'symbol': 'TBZ',
#   'txCount': '3'},
#  {'id': '0x00f598b011f8afafaf8b4f58a0d070825856d3be',
#   'symbol': 'WZTSBL',
#   'txCount': '4'},
#  {'id': '0x00fc270c9cc13e878ab5363d00354bebf6f05c15',
#   'symbol': 'VNXLU',
#   'txCount': '50'},
#  {'id': '0x010194ba9ca34ac26b097a5f204dfb47b21288ea',
#   'symbol': 'YYF',
#   'txCount': '845'},
#  {'id': '0x0101d8142fad2057c20481646eef5b2159b4712d',
#   'symbol': 'STARSHIP',
#   'txCount': '80'},
#  {'id': '0x01034c0875082d67880e01ea760a1b111bd7d520',
#   'symbol': 'PAID',
#   'txCount': '45'},
#  {'id': '0x010496d8f3269ee9b05060bdf40c2d66e83e61dd',
#   'symbol': 'DIGG',
#   'txCount': '181'},
#  {'id': '0x0104d2dd7fd2a28f216f11f37d4b9bf8f1fd1796',
#   'symbol': 'ATRI',
#   'txCount': '15'},
#  {'id': '0x01081c1181c7b6abef5f223326dc22debc0c3588',
#   'symbol': 'MUSKPRO',
#   'txCount': '11'},
#  {'id': '0x010b9cc87691e8432ac1417b3ff4c9f8f61e9b8e',
#   'symbol': 'CFI',
#   'txCount': '6'},
#  {'id': '0x010d4007cb7139515507c11c9388d7accf049100',
#   'symbol': '2020',
#   'txCount': '71'},
#  {'id': '0x010ea4d75515309e40db9cfa20ad4c4dba603afa',
#   'symbol': 'UNIBLOCK',
#   'txCount': '6'},
#  {'id': '0x010ea6e65fa50c0d44e2b90276b7ba1f16168601',
#   'symbol': 'YLTWB',
#   'txCount': '3'},
#  {'id': '0x010ee2900c5712fb9e5baffb33f3319ee547e967',
#   'symbol': 'IMPER',
#   'txCount': '22'},
#  {'id': '0x0116a4a3e2ab9d14ae0f482ab5275edd1315ab33',
#   'symbol': 'TRPV1',
#   'txCount': '4'},
#  {'id': '0x01176396450375d212c268ca6d5fcac5f1892d1d',
#   'symbol': 'DMH',
#   'txCount': '12'},
#  {'id': '0x011bc89da8b2b0ac96de0b02a91483f5350cf21b',
#   'symbol': 'ILV',
#   'txCount': '4'},
#  {'id': '0x011d5f48615119e53d11dea9d2a6e81036ff0f84',
#   'symbol': 'SCORE',
#   'txCount': '5'},
#  {'id': '0x01217729940055011f17befe6270e6e59b7d0337',
#   'symbol': 'VETH',
#   'txCount': '188'},
#  {'id': '0x01222eaa712c86591836f0f2e2b79a80c72e7842',
#   'symbol': 'YFPRO',
#   'txCount': '3'},
#  {'id': '0x01227558aea20d99d429b0b5cb1cae532e177cd0',
#   'symbol': 'GKP3R',
#   'txCount': '5'},
#  {'id': '0x0125e7f7ff7392f7f86cee5ec0459917e30e9c4c',
#   'symbol': 'PLAY',
#   'txCount': '8'},
#  {'id': '0x0128e4fccf5ef86b030b28f0a8a029a3c5397a94',
#   'symbol': 'FSP',
#   'txCount': '9692'},
#  {'id': '0x012b736cd20d125daa4afcf7c17fba91879a51d6',
#   'symbol': 'SWAG',
#   'txCount': '15'},
#  {'id': '0x012ba3ae1074ae43a34a14bca5c4ed0af01b6e53',
#   'symbol': 'TRUMP',
#   'txCount': '2482'},
#  {'id': '0x012d1a747904c04a2a09f1438be7ff35ef3b19c6',
#   'symbol': 'DEO',
#   'txCount': '27'},
#  {'id': '0x012f90820186a780b725b384eb5c8c17aeb6bfd1',
#   'symbol': 'GOLD',
#   'txCount': '5'},
#  {'id': '0x0132ff4697a6266c4fbfd38973ac6135364175ab',
#   'symbol': 'FMP',
#   'txCount': '49'},
#  {'id': '0x013446de940434f6f6c81d3bb7d7684f335c19d1',
#   'symbol': 'TFI',
#   'txCount': '26'},
#  {'id': '0x01365e778a27781ded122a8eb55790fc078fb7c0',
#   'symbol': 'ENEMA',
#   'txCount': '5'},
#  {'id': '0x01387115455a566acef031ee53ad998ba34395c0',
#   'symbol': 'RGB',
#   'txCount': '48'},
#  {'id': '0x013922eb7a32d04385a83453ae95f1c4d72be019',
#   'symbol': 'ORBS',
#   'txCount': '620'},
#  {'id': '0x013f7f36a977990f5203f5acb1cb0ef116a6d0c5',
#   'symbol': 'TARA',
#   'txCount': '20'},
#  {'id': '0x014153dbbb19cadd1bbd36dfdc5305d764381ea6',
#   'symbol': 'DEFI',
#   'txCount': '5'},
#  {'id': '0x0142e00e9298bafa015df9b39740ac88205b2d5f',
#   'symbol': 'FMC',
#   'txCount': '74'},
#  {'id': '0x0144f889f8ed5ec7962e2936683d3784b550c71a',
#   'symbol': 'ELE',
#   'txCount': '5'},
#  {'id': '0x01469b53f9dfd54ff7a97eba68c1e048575f4f8f',
#   'symbol': 'VAPE',
#   'txCount': '16'},
#  {'id': '0x014996a9533eded97a1549339fed784f3a727db6',
#   'symbol': 'GUNIT',
#   'txCount': '15'},
#  {'id': '0x014a543f767b3b06e31a811b0a75483ee8dfd72d',
#   'symbol': 'BNZ',
#   'txCount': '57'},
#  {'id': '0x014bade3f3701b583a8d19430d602feb20266a2a',
#   'symbol': 'sCORE',
#   'txCount': '4'},
#  {'id': '0x014c88aab660916f4eabc63c6b9231094e9fa782',
#   'symbol': 'tlpCORE',
#   'txCount': '4'},
#  {'id': '0x014cfd50aec123b053fc39e4724ca0fbf681a8d3',
#   'symbol': 'CHIHUA',
#   'txCount': '52'},
#  {'id': '0x014e42ae89b24738591e2f695e1ef6d95bd38619',
#   'symbol': 'ATF',
#   'txCount': '10'},
#  {'id': '0x015024b0d87dbb567f9e3d956bb0a495436ec3ba',
#   'symbol': 'DOGGY',
#   'txCount': '181'},
#  {'id': '0x01575b27d027838301c62b24a40ae896327a34cc',
#   'symbol': 'UNT',
#   'txCount': '15'},
#  {'id': '0x015b6f33f247ee526bfe4230f14b68c64cdbb4c4',
#   'symbol': 'AAB',
#   'txCount': '6'},
#  {'id': '0x015d62e1312ff52a2ad50294f923062fa03ec484',
#   'symbol': 'RELAX',
#   'txCount': '7'},
#  {'id': '0x0164f85a0d4ea7c2f938cc06d7fa38c69047bf75',
#   'symbol': 'DTN',
#   'txCount': '2'},
#  {'id': '0x016563e493a413eda6d1b16114085bf0e28b32c0',
#   'symbol': 'DPLAY',
#   'txCount': '9'},
#  {'id': '0x01672cadad43980353758c6a000e92a53cd101d5',
#   'symbol': 'MAT',
#   'txCount': '652'},
#  {'id': '0x016b6e79347fb12310e3a2ab83284f0581127efb',
#   'symbol': 'MATIC',
#   'txCount': '6'},
#  {'id': '0x016bf078abcacb987f0589a6d3beadd4316922b0',
#   'symbol': 'RSPT',
#   'txCount': '107'},
#  {'id': '0x016ee7373248a80bde1fd6baa001311d233b3cfa',
#   'symbol': 'BEAR',
#   'txCount': '4'},
#  {'id': '0x0176fa2361546128fb6cea56bfa3c265e0a68c94',
#   'symbol': 'Keykey',
#   'txCount': '13'},
#  {'id': '0x0178f94a3a0d86445597e1c7657cb299d77a8f1d',
#   'symbol': 'SHIT',
#   'txCount': '6'},
#  {'id': '0x017dd6711d1407be659d24b112e29e35908ca93d',
#   'symbol': 'BTG',
#   'txCount': '21'},
#  {'id': '0x0181150258d795758dac21f37711b8acc130bc9e',
#   'symbol': 'MAGADOGE',
#   'txCount': '5'},
#  {'id': '0x018226665b52b7d89c4de59a88602e116e43bf8c',
#   'symbol': 'TEST',
#   'txCount': '7'},
#  {'id': '0x018488c3cd23833e019595bef273ddbbd37d209c',
#   'symbol': 'AEGToken',
#   'txCount': '4'},
#  {'id': '0x01861ed7ecdb1cae8295668c767a43612f37e190',
#   'symbol': 'JOKER',
#   'txCount': '9'},
#  {'id': '0x0187b52e0b677f719989cbc54b21df31c14c7c69',
#   'symbol': 'CXB',
#   'txCount': '22'},
#  {'id': '0x018995ae3c8b1aa9a144fe4e3cf1390efe46e844',
#   'symbol': 'CUDOS',
#   'txCount': '24'},
#  {'id': '0x0189d31f6629c359007f72b8d5ec8fa1c126f95c',
#   'symbol': 'SNS',
#   'txCount': '18'},
#  {'id': '0x018a6106cb540af1ae6da985361afd5e176d1c00',
#   'symbol': 'WIZ',
#   'txCount': '2'},
#  {'id': '0x018c7c8c1d75feedbce95f2ba2b22d04b30da511',
#   'symbol': 'VREO',
#   'txCount': '15'},
#  {'id': '0x018c88d554c6dbc20b15aeaab59f992c323b5918',
#   'symbol': 'SUSHI V2',
#   'txCount': '11'},
#  {'id': '0x018d7d179350f1bb9853d04982820e37cce13a92',
#   'symbol': 'INX',
#   'txCount': '491'},
#  {'id': '0x018fb5af9d015af25592a014c4266a84143de7a0',
#   'symbol': 'MP3',
#   'txCount': '7565'},
#  {'id': '0x0197ca89cb1a21256cb4202c708e4816e4d50242',
#   'symbol': 'YFIC',
#   'txCount': '10'},
#  {'id': '0x01995786f1435743c42b7f2276c496a610b58612',
#   'symbol': 'SDZ',
#   'txCount': '17'},
#  {'id': '0x019ba8b3e5090b1b806b968fed1e01d21a1ee620',
#   'symbol': 'TREY',
#   'txCount': '14'},
#  {'id': '0x01a1361e74f4617b654bfae40ceca769d27b0b99',
#   'symbol': 'FUCK-YOU',
#   'txCount': '7'},
#  {'id': '0x01afa0ec445508343e64cbd717491ef152ef823f',
#   'symbol': 'STORM',
#   'txCount': '6'},
#  {'id': '0x01b000c3076a6af1f889f2be146f60c290f0aa3a',
#   'symbol': 'JUGG',
#   'txCount': '4'},
#  {'id': '0x01b0fa10144f8d2d37bd3baea25ed1ebe2be5a09',
#   'symbol': 'YFV',
#   'txCount': '2'},
#  {'id': '0x01b2b62e613b44a4bfe71ec9ccb6a6465dd75849',
#   'symbol': 'HRNY',
#   'txCount': '36'},
#  {'id': '0x01b68fc481391a029721a97c45bec5acec0be439',
#   'symbol': 'PEX',
#   'txCount': '1'},
#  {'id': '0x01b7e3c16936cabfb57bc32ed6790e76ef142bc2',
#   'symbol': 'CRX',
#   'txCount': '23'},
#  {'id': '0x01b8bcc8b75dd86025b455373f3c0814a060e6a8',
#   'symbol': 'DGRO',
#   'txCount': '110'},
#  {'id': '0x01b9f7aca53edbf45b411a7a292b0c20227beac7',
#   'symbol': 'BTSWAP',
#   'txCount': '30'},
#  {'id': '0x01bc52a31696ed70197f5cb3f8e28703bff95a86',
#   'symbol': 'BUFF',
#   'txCount': '13'},
#  {'id': '0x01beace2fdc8cec1ce8177076e2bec39943f0941',
#   'symbol': 'UBTC',
#   'txCount': '5'},
#  {'id': '0x01bf2c6ff1c43135086e925ad236fa9218e4f9d2',
#   'symbol': 'SNAKE',
#   'txCount': '3'},
#  {'id': '0x01bf4909e6bbe9ab6cdd1b92ff750bb64b1710e4',
#   'symbol': 'IBLUE',
#   'txCount': '297'},
#  {'id': '0x01c11255b653f6ce2a5cb3c70c7d269133197aba',
#   'symbol': 'PUSH',
#   'txCount': '20'},
#  {'id': '0x01c2d503c83a40a91986d54a804935622d5f756c',
#   'symbol': 'PDOGE',
#   'txCount': '69'},
#  {'id': '0x01c8857057326b8f64dcb5cba6d802dcd132946e',
#   'symbol': 'XAT',
#   'txCount': '20'},
#  {'id': '0x01cafabb9f33be3d65c22469ec011b4adb20bfcb',
#   'symbol': 'LAMBO',
#   'txCount': '7'},
#  {'id': '0x01cd82cdf05741e4aadb18edd6db073e5b3a01b3',
#   'symbol': 'VSO',
#   'txCount': '8'},
#  {'id': '0x01ce398a2a59d164f366762ee70c596de06e9482',
#   'symbol': 'eRSDL',
#   'txCount': '66'},
#  {'id': '0x01ceac209b3d977fcdf13be403abc9a45490c4ea',
#   'symbol': 'TAX1',
#   'txCount': '44'},
#  {'id': '0x01d05820685dc73f73fdda30a59e827c0065795e',
#   'symbol': 'AERUS',
#   'txCount': '43'},
#  {'id': '0x01d454ffc3f0b77f3f316d4c88230263c2af7aba',
#   'symbol': 'MKD',
#   'txCount': '4'},
#  {'id': '0x01d5ca206cbb7a42dd227c9c554b24d3eba2190b',
#   'symbol': 'MMT',
#   'txCount': '49'},
#  {'id': '0x01d8531005ce845485e7150e7ef8761c7ba63e20',
#   'symbol': 'CZ',
#   'txCount': '1153'},
#  {'id': '0x01d8c1b8c8fe72228052db95c52d2fc8e29d20c6',
#   'symbol': 'TWB',
#   'txCount': '1'},
#  {'id': '0x01da03b4438d495d8708ec0efcb6d46ce6d81380',
#   'symbol': 'SAFEDOGE',
#   'txCount': '107'},
#  {'id': '0x01da76dea59703578040012357b81ffe62015c2d',
#   'symbol': 'crYETH',
#   'txCount': '2'},
#  {'id': '0x01ddb75a2ec1e6f9b21c21ce6ec909725f434e92',
#   'symbol': 'EQF',
#   'txCount': '34'},
#  {'id': '0x01de60abe48bf5deb60e82b4b8975d7222bdbe7c',
#   'symbol': 'BOOP2',
#   'txCount': '5'},
#  {'id': '0x01df2b4b78a47db8c61d46aaa856b0ebe596f910',
#   'symbol': 'OCTO',
#   'txCount': '2'},
#  {'id': '0x01e0b2c5dde3815ac275c16ac50c4e7a4c0ac0b8',
#   'symbol': 'EXC',
#   'txCount': '58'},
#  {'id': '0x01e140367902ded57cc352bb4438b1acc7b5e4d0',
#   'symbol': 'CTK',
#   'txCount': '418'},
#  {'id': '0x01e25fbababa24bfc0db90b681d2fa0b927b6605',
#   'symbol': 'REMAXD',
#   'txCount': '10'},
#  {'id': '0x01e5870de90578be6a792a82a087750c999d8738',
#   'symbol': 'INSHU',
#   'txCount': '91'},
#  {'id': '0x01e6e3d6faad1e9e3f85419ea9bbe8fd65b34932',
#   'symbol': 'HKKO',
#   'txCount': '6'},
#  {'id': '0x01eace2b0b1c37b036e094906753c1d3c426c155',
#   'symbol': 'JOKER',
#   'txCount': '9'},
#  {'id': '0x01eaea2ef0d0cf1ad856716dc0a98bdd7d269f88',
#   'symbol': 'LOTUS',
#   'txCount': '2'},
#  {'id': '0x01eb2bdc6d097ae8195546efa5e55d430c11a302',
#   'symbol': 'KP5RV1',
#   'txCount': '25'},
#  {'id': '0x01ef96b79b24771dc1727560d330d97737a789f6',
#   'symbol': 'ZP3R',
#   'txCount': '31'},
#  {'id': '0x01f11a0d08a3e63914ca9be7b98329dd6ca2ef06',
#   'symbol': 'SSF',
#   'txCount': '10'},
#  {'id': '0x01f1881469c303812a3f4833f3439fdb57c5f741',
#   'symbol': 'ZTES',
#   'txCount': '3'},
#  {'id': '0x01f4d5ba49b2c1647148955e0a1d3c9c0eee1f40',
#   'symbol': 'YFC',
#   'txCount': '330'},
#  {'id': '0x01f64161e44d0453f905eebed52e4c1176339835',
#   'symbol': 'yC',
#   'txCount': '0'},
#  {'id': '0x01f666dbc313ae35702e41958a11b17c521e8a16',
#   'symbol': '$HIT',
#   'txCount': '1'},
#  {'id': '0x01f8989c1e556f5c89c7d46786db98eeaae82c33',
#   'symbol': 'UNI-V2',
#   'txCount': '0'},
#  {'id': '0x01fa17a1b38a6335b7ad2307db6bef309d2ba981',
#   'symbol': 'CEX',
#   'txCount': '9'},
#  {'id': '0x01fa555c97d7958fa6f771f3bbd5ccd508f81e22',
#   'symbol': 'CVL',
#   'txCount': '24'},
#  {'id': '0x01fd80f96bbd3ec95f5eeec1777b1fbb0e33a864',
#   'symbol': 'AUT',
#   'txCount': '62'},
#  {'id': '0x01ff50f8b7f74e4f00580d9596cd3d0d6d6e326f',
#   'symbol': 'BFT',
#   'txCount': '2744'},
#  {'id': '0x02002975df63e95b405a0b7008119351bcbade4a',
#   'symbol': 'PFT',
#   'txCount': '2'},
#  {'id': '0x0202be363b8a4820f3f4de7faf5224ff05943ab1',
#   'symbol': 'UFT',
#   'txCount': '47032'},
#  {'id': '0x02044c9d2da3fd33ed800716693396eeeceef918',
#   'symbol': 'BTF',
#   'txCount': '235'},
#  {'id': '0x02048d70104baa4f6f267681a1a18161a570fc85',
#   'symbol': 'DOGDEFI',
#   'txCount': '10'},
#  {'id': '0x02080b9c5d393a19ff311bb41401dcdac8a0b3dc',
#   'symbol': 'ZIL',
#   'txCount': '12'},
#  {'id': '0x020810d775fc019480cd56ecb960389d3477039d',
#   'symbol': 'GIL',
#   'txCount': '165'},
#  {'id': '0x0209ce3516587cc4a22b54c024b2ee724c117036',
#   'symbol': 'miniCORE',
#   'txCount': '363'},
#  {'id': '0x020d0d5ceae6678d3d9afc938a48e583ac4ee208',
#   'symbol': 'SUSHI',
#   'txCount': '7'},
#  {'id': '0x020d5e6fec03d0144a2681cfc0fd3c9255d6d7c2',
#   'symbol': 'MSWAP',
#   'txCount': '89'},
#  {'id': '0x0210e38a37177fb3c99e444642382c5a41668947',
#   'symbol': 'LOVE',
#   'txCount': '24'},
#  {'id': '0x02122fcb9730d0bfbfc88c6df3d508a5b2968d1d',
#   'symbol': 'BOND',
#   'txCount': '11'},
#  {'id': '0x0212aa97cb0293516548f5a80aa3f51bebd131e0',
#   'symbol': 'MF',
#   'txCount': '871'},
#  {'id': '0x0214fc077cbe222542ff2da74dfe8cbdabd5c1c5',
#   'symbol': 'NAS',
#   'txCount': '210'},
#  {'id': '0x021576770cb3729716ccfb687afdb4c6bf720cb6',
#   'symbol': 'uFFYI',
#   'txCount': '1490'},
#  {'id': '0x021868c129a953a39846e1b9d47b7249407be584',
#   'symbol': 'TNK',
#   'txCount': '19'},
#  {'id': '0x021cf14d19a23671954124a3253251492c9edc9b',
#   'symbol': 'BVLT',
#   'txCount': '2'},
#  {'id': '0x021d16069d1c46b238a2325c6a900fe9108e7218',
#   'symbol': 'TIK',
#   'txCount': '26'},
#  {'id': '0x021d58863d6a8cfc30c24221944a28e18efc677b',
#   'symbol': 'ZYT',
#   'txCount': '11'},
#  {'id': '0x022057c3ef9166433750165bfda21d52988e0756',
#   'symbol': 'AO',
#   'txCount': '309'},
#  {'id': '0x0222be1f1b8413b2d7d76ebfc9e0285c1300692f',
#   'symbol': 'GLOX',
#   'txCount': '2012'},
#  {'id': '0x02269d100b56fb01c5a9f81b679a12bc431461b5',
#   'symbol': 'KING-INU',
#   'txCount': '117'},
#  {'id': '0x02278e5570ed2e95429572ec18dd4ae5831d6883',
#   'symbol': 'AKN',
#   'txCount': '25'},
#  {'id': '0x0228528581c01a303d59d8cf6b72bd5a5d219458',
#   'symbol': 'OKNC',
#   'txCount': '3'},
#  {'id': '0x022882d9fcf023e57926e4e01d1b137aabd93416',
#   'symbol': 'ARKA',
#   'txCount': '7'},
#  {'id': '0x0228e9efa309d6800a0338dd266d4193ed3ab33c',
#   'symbol': 'KAP',
#   'txCount': '1'},
#  {'id': '0x022a11c4b82eb03788cba69fca7c7ab3cfd5a313',
#   'symbol': 'SAFESEX',
#   'txCount': '12'},
#  {'id': '0x022cc93b66a7d28ad6887d1d5a60642d5b02837b',
#   'symbol': 'NARUTO',
#   'txCount': '35'},
#  {'id': '0x022d99b653fe22120ecbc496bb67f723b55bba8c',
#   'symbol': 'PGG',
#   'txCount': '8'},
#  {'id': '0x022f7481c4d975449a3619ca4d835446f2d8a569',
#   'symbol': 'STKR9',
#   'txCount': '3'},
#  {'id': '0x022fb5a50ab8a92dc7aaa724e4b7f3d4640a3add',
#   'symbol': 'RXBL',
#   'txCount': '7'},
#  {'id': '0x0231a0b0fe7691ac0b1e52e3c0721d3004e874c0',
#   'symbol': 'DARKX',
#   'txCount': '2'},
#  {'id': '0x02322569685a2fa5090fafae905208abb64a847e',
#   'symbol': 'GAINS',
#   'txCount': '18'},
#  {'id': '0x023593af6277227a0252b7b1eef9b0fff4b04e62',
#   'symbol': 'YYY',
#   'txCount': '3'},
#  {'id': '0x0238ef2dec28ce4f532ddd3b05a252f86b046550',
#   'symbol': 'MWT',
#   'txCount': '14'},
#  {'id': '0x023b30999a2020d40787e1cca8781be9e28593d3',
#   'symbol': 'HOT',
#   'txCount': '16'},
#  {'id': '0x023ebb622f461a15a344edc45e6a5eabb5a68e03',
#   'symbol': 'DYX',
#   'txCount': '859'},
#  {'id': '0x023ebf4e1feea224f375d6fb06d34b1f56cffad0',
#   'symbol': 'e-HR',
#   'txCount': '1'},
#  {'id': '0x023f58e2de536fdd92a0a40635f849f9b8903bda',
#   'symbol': 'LFNT',
#   'txCount': '28'},
#  {'id': '0x0240e59e6ae33b58db7360f7c693429eab7d4ac3',
#   'symbol': 'BTC',
#   'txCount': '1'},
#  {'id': '0x02421250e4d6c12913c15c7c2e9b0d99d5451224',
#   'symbol': 'OXYI',
#   'txCount': '9'},
#  {'id': '0x0243f77b6571cfab4cc3541c3599e02d019d0c49',
#   'symbol': 'ethSWAP',
#   'txCount': '38'},
#  {'id': '0x0245242a3a9bba63e7cec348de220f96a908053b',
#   'symbol': 'MOOD',
#   'txCount': '11'},
#  {'id': '0x0245bb9aa768a65760a748b7272b9d8b66de710b',
#   'symbol': 'YFR',
#   'txCount': '4'},
#  {'id': '0x0246890c9278d0a786812dda4dd20361ed13cda0',
#   'symbol': 'NASHU',
#   'txCount': '29'},
#  {'id': '0x02474f94945b9d1edaff49fdaab3ad92c96ac55f',
#   'symbol': 'VCORE',
#   'txCount': '4'},
#  {'id': '0x024946259b9ca66e90815ac97a727fd847307756',
#   'symbol': 'OSINU',
#   'txCount': '18'},
#  {'id': '0x024c5cb183e0978d89d061ba6baeea19441abc16',
#   'symbol': 'JAM',
#   'txCount': '46'},
#  {'id': '0x024cee421efcafb2d7231489c719af30a6ea4ab6',
#   'symbol': 'CAVRE',
#   'txCount': '20'},
#  {'id': '0x024f4a3090863d97c1e5b531310a3d3c335e11a5',
#   'symbol': 'REVERB',
#   'txCount': '9'},
#  {'id': '0x02538f3480770ad7028418852c8f559eac5f1478',
#   'symbol': 'XBOM3',
#   'txCount': '3'},
#  {'id': '0x025463ad1c0325ea884f4eba3c97562bd1e4766a',
#   'symbol': 'TOPO',
#   'txCount': '8'},
#  {'id': '0x025600d1b1fbfbe9e1ee1108bf4aae6ec53c4170',
#   'symbol': 'TRFLE',
#   'txCount': '3'},
#  {'id': '0x02562776e730887cf838ea5576a4ba19e9c46897',
#   'symbol': 'ALBB',
#   'txCount': '19'},
#  {'id': '0x0258014e3f450b5a97efec0b34046ee5df3a4882',
#   'symbol': 'BEL',
#   'txCount': '14'},
#  {'id': '0x0258595bb804822f0c3aa1ab64345fc5e5b33139',
#   'symbol': 'DTRADE',
#   'txCount': '13'},
#  {'id': '0x0258f474786ddfd37abce6df6bbb1dd5dfc4434a',
#   'symbol': 'ORN',
#   'txCount': '44143'},
#  {'id': '0x02596ad70aa277d52d163be2f98eb20be9240180',
#   'symbol': 'MOG',
#   'txCount': '21'},
#  {'id': '0x02600b5683df3ffa713d70b0057bc077552bc6ef',
#   'symbol': 'SHIBPUP',
#   'txCount': '22'},
#  {'id': '0x0260853e7313725691bd0c562bc7d27dd7845a9b',
#   'symbol': 'MONSTER',
#   'txCount': '32'},
#  {'id': '0x02614aeb11cfbffdb68bbee50a498ae947181dae',
#   'symbol': 'CALL',
#   'txCount': '220'},
#  {'id': '0x026195ce819f1cb4fa872ce306b14b91ab16a3ab',
#   'symbol': 'YAMSF',
#   'txCount': '16'},
#  {'id': '0x0263e1dcfcaaad8fd4e840fe4b22854485a561f0',
#   'symbol': 'BTL',
#   'txCount': '19'},
#  {'id': '0x026450c9a8cba84dc7c3826f1d48b0ad914481f5',
#   'symbol': 'VTX',
#   'txCount': '3'},
#  {'id': '0x0264cf5ab570b450b81bbbe65f2171796c730934',
#   'symbol': 'GEKKO',
#   'txCount': '395'},
#  {'id': '0x026645d0c6540e7495e44272c27cb51ec64d525f',
#   'symbol': 'OMFY',
#   'txCount': '9'},
#  {'id': '0x0268f0dd879cea41210b8191149d06bd318a56e7',
#   'symbol': 'EDEN',
#   'txCount': '0'},
#  {'id': '0x026b8d2edda7882b0612607dc0a31a1bbc1a9e1c',
#   'symbol': 'XBTC',
#   'txCount': '19'},
#  {'id': '0x026d146d3c4515724998369da21de2ea912c73cc',
#   'symbol': 'CONV',
#   'txCount': '47'},
#  {'id': '0x026e62dded1a6ad07d93d39f96b9eabd59665e0d',
#   'symbol': 'BIRD',
#   'txCount': '22'},
#  {'id': '0x026e96a9fcfeb4436624d64408786420b42e121f',
#   'symbol': 'SBREE',
#   'txCount': '11'},
#  {'id': '0x0270efbd3552172f4edaa38c294bfcdde7a27091',
#   'symbol': 'KINKY',
#   'txCount': '4'},
#  {'id': '0x02736ee4694043479fb71ad670b0395fa015105a',
#   'symbol': 'FRCORE',
#   'txCount': '43'},
#  {'id': '0x02744731e4a53c9f1b664350df2b09dba6a6c653',
#   'symbol': 'lt',
#   'txCount': '5'},
#  {'id': '0x02756339d28a1af08b114ee5d8c531c9898a2b08',
#   'symbol': 'JPLUS',
#   'txCount': '9'},
#  {'id': '0x0275b940c5eeb4f1c923dd886c9d87a04f0b90ea',
#   'symbol': 'POLA',
#   'txCount': '14'},
#  {'id': '0x0275e1001e293c46cfe158b3702aade0b99f88a5',
#   'symbol': 'OIL',
#   'txCount': '3131'},
#  {'id': '0x0276604603740b88f7df4986529e261b1768e0e3',
#   'symbol': 'XED',
#   'txCount': '9'},
#  {'id': '0x0277d9ad7889dd909d06be863b122844ae9f945a',
#   'symbol': 'ORAO',
#   'txCount': '50'},
#  {'id': '0x0278b15daa019973ec36cd0732eaa9611e2d2ffe',
#   'symbol': 'TREE',
#   'txCount': '8'},
#  {'id': '0x027ab8869caa186755cba064c7e7764880714f11',
#   'symbol': 'YCFF',
#   'txCount': '28'},
#  {'id': '0x027bec2b1281884e970f1c999680ae90d74cf32b',
#   'symbol': 'zzz',
#   'txCount': '6'},
#  {'id': '0x027cd86e892c3f8fd482cb30dc73de030c546503',
#   'symbol': 'S2017',
#   'txCount': '32'},
#  {'id': '0x027daa4c3244ce3c8711bba1dd132127320bba43',
#   'symbol': 'DEAN',
#   'txCount': '34'},
#  {'id': '0x027dd02fb1aecc5b47084310eec436f55ebb508f',
#   'symbol': 'CKIT',
#   'txCount': '2'},
#  {'id': '0x028071d9c517f5cd65b6803ea23b4d8eb40c64d9',
#   'symbol': 'ASHA',
#   'txCount': '48'},
#  {'id': '0x028a0902ec48857a5f2b9a6b3500661efa6e9a3c',
#   'symbol': 'p3x',
#   'txCount': '3'},
#  {'id': '0x028aa75a70ddc7428d9cef884221879e27916b14',
#   'symbol': 'xMOON',
#   'txCount': '12'},
#  {'id': '0x028b7889ebecf22f9f0e2a6d7f75782f88108f19',
#   'symbol': 'OW',
#   'txCount': '17'},
#  {'id': '0x028bf883b441b9435d0e32767d84a1c07122bc32',
#   'symbol': 'COFI',
#   'txCount': '5'},
#  {'id': '0x0290b327a8583bd6fa63c130b732a808864e55fc',
#   'symbol': 'MDS',
#   'txCount': '1025'},
#  {'id': '0x029177c1fd6190a8dfc85d9a3e13bf78581bd3d6',
#   'symbol': 'YCD',
#   'txCount': '23'},
#  {'id': '0x02922b267d831ae672e70480d3de48743711db28',
#   'symbol': 'DiBi',
#   'txCount': '4'},
#  {'id': '0x029304e22ec569ecf447c065421c4fefe16a1e6b',
#   'symbol': 'place',
#   'txCount': '3'},
#  {'id': '0x0297083eef9c04ee22c89187b13363af2249042b',
#   'symbol': 'aKP9R',
#   'txCount': '18'},
#  {'id': '0x029b8799de1304c7579d5fcf2a8bbbf7d3e888b9',
#   'symbol': 'MNDF',
#   'txCount': '64'},
#  {'id': '0x029bbc58aa50f71efc517c52c6021b64852d1e29',
#   'symbol': 'SHIB',
#   'txCount': '2'},
#  {'id': '0x029c4d6a757d275a82d494282385d1b74013c599',
#   'symbol': 'RBC',
#   'txCount': '14'},
#  {'id': '0x02a094c8e455bc96e9c6a6c0f03747a1323e82cd',
#   'symbol': 'sPolka',
#   'txCount': '27'},
#  {'id': '0x02a12a0074229d18d755069b380b5fe5cac2df3b',
#   'symbol': 'Inf',
#   'txCount': '421'},
#  {'id': '0x02a1bdf9dab493aef315d4e79c83d791f1a8371b',
#   'symbol': 'SUSF',
#   'txCount': '30'},
#  {'id': '0x02a643d43cc72671bec8beb6c163945160e50e52',
#   'symbol': 'TLPB',
#   'txCount': '5'},
#  {'id': '0x02aa56a0fcd57a57b934cff6e5274915ddfbe14c',
#   'symbol': 'CTi',
#   'txCount': '8'},
#  {'id': '0x02ae09ce56760bc212c62916c50f8c4eb239eef6',
#   'symbol': 'BRICH',
#   'txCount': '4'},
#  {'id': '0x02ae602c7563fcffa7d3bf2941de7348161610ee',
#   'symbol': 'INERTIA',
#   'txCount': '43'},
#  {'id': '0x02b39629beac67a41e6e081ec267bea60b90e4d9',
#   'symbol': '$BOSON',
#   'txCount': '41'},
#  {'id': '0x02b6361bbec213bcc34756bbd2877831d92a6c84',
#   'symbol': 'WALL',
#   'txCount': '191'},
#  {'id': '0x02b6449d473f107a6205cadfe54baecd853fad59',
#   'symbol': 'ULA',
#   'txCount': '13'},
#  {'id': '0x02b6b98c9f855b9f058e1a6a14200663d0c06970',
#   'symbol': 'AMD',
#   'txCount': '67'},
#  {'id': '0x02ba7b2026d26896bc1368e6bef4349d2f595b68',
#   'symbol': 'HLT',
#   'txCount': '381'},
#  {'id': '0x02bfaa0a2050affbedd3449aec83157f3fb323c2',
#   'symbol': 'LMIB',
#   'txCount': '8'},
#  {'id': '0x02c4c78c462e32cca4a90bc499bf411fb7bc6afb',
#   'symbol': 'IDT',
#   'txCount': '4'},
#  {'id': '0x02c65013b5846a2a34b54eaf7984b93c126480fc',
#   'symbol': 'SDN',
#   'txCount': '19'},
#  {'id': '0x02cbd176e86e363fe84cda7a6c7bb885de40b57f',
#   'symbol': 'YFN',
#   'txCount': '5'},
#  {'id': '0x02cd28ee6017df3b5c69b0b31f9aaddf65aa26e8',
#   'symbol': 'KTN',
#   'txCount': '11'},
#  {'id': '0x02cf994ff0cb1d0778e87ece735abc63322d3140',
#   'symbol': 'KOIL',
#   'txCount': '11'},
#  {'id': '0x02d2585eb37eed44f00c8488541b9d95bc68524e',
#   'symbol': 'DDF',
#   'txCount': '38'},
#  {'id': '0x02d5e844e5b885716db7068aa27f17378d63766b',
#   'symbol': 'yRise',
#   'txCount': '21'},
#  {'id': '0x02d6b2dc550aa2eec80932180ec633e8e529d18b',
#   'symbol': 'STND',
#   'txCount': '42'},
#  {'id': '0x02d7b659389d537912b313611cbc5a7f7ed615a9',
#   'symbol': 'KP6R',
#   'txCount': '19'},
#  {'id': '0x02d80216ddde8ff6d7392f591302b0d5d95b90bd',
#   'symbol': 'YFK',
#   'txCount': '14'},
#  {'id': '0x02d9a9d0e876be9719d745c77a894714649abe33',
#   'symbol': 'UNFUD',
#   'txCount': '12'},
#  {'id': '0x02ddbc11e2447108dd983e60fa0a7d5a7d7b563a',
#   'symbol': 'SEPPUKU',
#   'txCount': '331'},
#  {'id': '0x02e3048e9eb0d730ca3f5f47b890c83d571d9a35',
#   'symbol': 'ARCH',
#   'txCount': '7'},
#  {'id': '0x02e4fecc3d55d41b936817dc17f22129108e3d6d',
#   'symbol': 'STK',
#   'txCount': '10'},
#  {'id': '0x02e54201f114f8b0247047c7966340d059e3829e',
#   'symbol': 'PSP',
#   'txCount': '6'},
#  {'id': '0x02e578a87851670839d351d9372b10e2a580aec3',
#   'symbol': 'K33PR',
#   'txCount': '20'},
#  {'id': '0x02e70911d29e05cb85a420c6fbf713d021639fa9',
#   'symbol': 'KAWAINU',
#   'txCount': '17'},
#  {'id': '0x02e948419babd62089cde512720acf4f46d8c0a8',
#   'symbol': 'DOKI',
#   'txCount': '8'},
#  {'id': '0x02ec1ade01cc61c264e9ae9b2a65b42d729807e4',
#   'symbol': 'Terra',
#   'txCount': '20'},
#  {'id': '0x02ec96261b8ea3fb7bc9e046aa626204a97ca446',
#   'symbol': 'INDEX20',
#   'txCount': '14'},
#  {'id': '0x02eca910cb3a7d43ebc7e8028652ed5c6b70259b',
#   'symbol': 'PTERIA',
#   'txCount': '16838'},
#  {'id': '0x02ee809fd5b99d87f6e2c8d7974e1ce16f1b4d33',
#   'symbol': 'ENCORE',
#   'txCount': '55'},
#  {'id': '0x02ef41f4ef3b02f308cfc61644db5135822aeebe',
#   'symbol': 'YXT',
#   'txCount': '97'},
#  {'id': '0x02f1f87f70cd4f4bc9722ead7bb12cbeaeb26fd9',
#   'symbol': 'YFINE',
#   'txCount': '17'},
#  {'id': '0x02f2d4a04e6e01ace88bd2cd632875543b2ef577',
#   'symbol': 'PKG',
#   'txCount': '426'},
#  {'id': '0x02f3a1819851d127bcd6f468253d7a498567eee0',
#   'symbol': 'GSFY',
#   'txCount': '2843'},
#  {'id': '0x02f4b9812b979a8889f1ac71223d3ea956b8d478',
#   'symbol': 'PRC',
#   'txCount': '107'},
#  {'id': '0x02f61fd266da6e8b102d4121f5ce7b992640cf98',
#   'symbol': 'LIKE',
#   'txCount': '23'},
#  {'id': '0x02f6a50f89a7b98ea39813538e590238d8bc5c48',
#   'symbol': 'DIA',
#   'txCount': '12'},
#  {'id': '0x02f7bd798e765369a9d204e9095b2a526ef01667',
#   'symbol': 'FMUSK',
#   'txCount': '13'},
#  {'id': '0x02fdd6866333d8cd8b1ca022d382080698060bc2',
#   'symbol': '69C',
#   'txCount': '1132'},
#  {'id': '0x02fdeea649d0291a987438fdaab5a71ed623471f',
#   'symbol': 'ArtDeco',
#   'txCount': '102'},
#  {'id': '0x02feb15a3b9d2b97010fd98d96bd4dc657c176a8',
#   'symbol': 'iTOK',
#   'txCount': '4'},
#  {'id': '0x030385efc63ebda6021d9098b1fcc422547d83d3',
#   'symbol': '$TACO',
#   'txCount': '4'},
#  {'id': '0x03042482d64577a7bdb282260e2ea4c8a89c064b',
#   'symbol': 'CNTR',
#   'txCount': '10630'},
#  {'id': '0x030427ec61b32979dd6c4377838140f5f587f80e',
#   'symbol': 'POS',
#   'txCount': '18'},
#  {'id': '0x03066da434e5264ef0b32f787923f974a5726fdc',
#   'symbol': 'BCS',
#   'txCount': '16996'},
#  {'id': '0x0306894d1a68aaf132509f7eb092c348062d0151',
#   'symbol': 'VAMP',
#   'txCount': '6'},
#  {'id': '0x0306e522cefd3cdc3ce63a60686eb1a0c0e6f467',
#   'symbol': 'ADOGE',
#   'txCount': '6'},
#  {'id': '0x030871127463a13accc1f57b7507641540951918',
#   'symbol': 'MIKINU',
#   'txCount': '23'},
#  {'id': '0x0308766aef1fa69d44dd7aced291130c45f712ff',
#   'symbol': 'GU4RD',
#   'txCount': '4'},
#  {'id': '0x030961a3e155fb0a5f582056f65f57904a19a6c1',
#   'symbol': 'SIL',
#   'txCount': '67'},
#  {'id': '0x030a9cc49f53f5c0e00953fb7ab54273d46e14dd',
#   'symbol': 'KAPPD',
#   'txCount': '31'},
#  {'id': '0x030b6dc5106a14d16831dd47c812a401e9f3b8aa',
#   'symbol': 'MKS',
#   'txCount': '4'},
#  {'id': '0x030ba81f1c18d280636f32af80b9aad02cf0854e',
#   'symbol': 'aWETH',
#   'txCount': '33'},
#  {'id': '0x030bba8c95c8b4125744d770e25ca646058d4857',
#   'symbol': 'RECHECK',
#   'txCount': '28'},
#  {'id': '0x030c1a0bcd18af48dcb7f383b3f97742e454f7e5',
#   'symbol': 'WLON',
#   'txCount': '305'},
#  {'id': '0x030ff14780b6d5c5f3be0c776de48f9549aaeb6e',
#   'symbol': 'JDAO',
#   'txCount': '15'},
#  {'id': '0x031000ba195e6bb28537b7006789f327cc69bcd5',
#   'symbol': 'RBTC',
#   'txCount': '19'},
#  {'id': '0x0316155671a6b372d68323ec798f597675110896',
#   'symbol': 'COF',
#   'txCount': '70'},
#  {'id': '0x0316eb71485b0ab14103307bf65a021042c6d380',
#   'symbol': 'HBTC',
#   'txCount': '1057'},
#  {'id': '0x0319b090a3eda2d432af27c8af80c268528f1880',
#   'symbol': 'MGC',
#   'txCount': '17'},
#  {'id': '0x03241323e870b4d4df639f86188fabf256f7fc57',
#   'symbol': 'GLN',
#   'txCount': '4'},
#  {'id': '0x0324a25c1b799fd268fbfd5670426f86dbb1412d',
#   'symbol': 'TESTES',
#   'txCount': '68'},
#  {'id': '0x03261cd0bcb30e009da99382b53058f83eaf77c8',
#   'symbol': 'OM',
#   'txCount': '9'},
#  {'id': '0x0327112423f3a68efdf1fcf402f6c5cb9f7c33fd',
#   'symbol': 'BTC++',
#   'txCount': '65'},
#  {'id': '0x03282f2d7834a97369cad58f888ada19eec46ab6',
#   'symbol': 'GEX',
#   'txCount': '112'},
#  {'id': '0x0329b4828dece9c68e21ce4d15883baf44d0988d',
#   'symbol': 'LPF',
#   'txCount': '7'},
#  {'id': '0x032ae2bd448904e0d468167dc25b4c35d3d72a36',
#   'symbol': 'FAMI',
#   'txCount': '20'},
#  {'id': '0x032c1cfc0c1a6c6960e551e8aac16c1c973c3572',
#   'symbol': 'YBGL',
#   'txCount': '28'},
#  {'id': '0x03303f2e0ccb295c59cfd35e86fb2361e212a76a',
#   'symbol': 'MAK',
#   'txCount': '262'},
#  {'id': '0x033239f51c751e688b12681fb3ccf286b3818a69',
#   'symbol': 'CYBER',
#   'txCount': '6'},
#  {'id': '0x03356e9b3271168ee51b5092a7b0740be8643da1',
#   'symbol': 'FCL',
#   'txCount': '61'},
#  {'id': '0x03394721598f02130d59d43b3e580a60cef89bbe',
#   'symbol': 'RUB',
#   'txCount': '9'},
#  {'id': '0x033e223870f766644f7f7a4b7dc2e91573707d06',
#   'symbol': 'Zin',
#   'txCount': '1785'},
#  {'id': '0x0341049bbf89b6255723e411fa1ff8655dcd9d69',
#   'symbol': 'JOYS',
#   'txCount': '246'},
#  {'id': '0x034455c8a9882bf44c9704c780a55198e05ba559',
#   'symbol': 'LMS',
#   'txCount': '5114'},
#  {'id': '0x03456f538f359a79368533d478c6e44c46fc554a',
#   'symbol': 'ORO',
#   'txCount': '3'},
#  {'id': '0x0347337a78d51bbb75550d258af04f5fe5efb57b',
#   'symbol': 'RSC',
#   'txCount': '74'},
#  {'id': '0x034b14ffba61cf4f3c823f4dd92e0d70679a8af5',
#   'symbol': 'KEEP',
#   'txCount': '34'},
#  {'id': '0x034bc8d262c0d00cb24a5e73152420b9701931c6',
#   'symbol': 'BFA',
#   'txCount': '8'},
#  {'id': '0x034c46cfafdecc9956e4283c1ae0d913c7d26fee',
#   'symbol': 'CPD',
#   'txCount': '24'},
#  {'id': '0x034e141f1e0507e17cb344e544229ccdf0f8cfbf',
#   'symbol': 'POFI',
#   'txCount': '42'},
#  {'id': '0x034f9e67af90233805c88ab3a8bd84880b4b0c42',
#   'symbol': 'RAGE',
#   'txCount': '17'},
#  {'id': '0x035066676b55a745eff77182d5d554b43f1ccafe',
#   'symbol': 'zSK',
#   'txCount': '39'},
#  {'id': '0x03537bb1f476f7225a2671c1bd9e1f3d1b6e1ef6',
#   'symbol': 'BUSHU',
#   'txCount': '18'},
#  {'id': '0x03542773ff03e6bfc17f70cb29c0b43115399a8b',
#   'symbol': 'ERA',
#   'txCount': '1351'},
#  {'id': '0x0355a2b288ee13f7cf6666cf2b6b690761c5e9fa',
#   'symbol': 'UNO',
#   'txCount': '32'},
#  {'id': '0x035824ceddba0e473e217b43eaa7d0e6ddeddd93',
#   'symbol': 'BFC',
#   'txCount': '84'},
#  {'id': '0x03598fd358335b1955569b4362751622d84d1a5c',
#   'symbol': 'MJ',
#   'txCount': '1'},
#  {'id': '0x035bfe6057e15ea692c0dfdcab3bb41a64dd2ad4',
#   'symbol': 'ULU',
#   'txCount': '8004'},
#  {'id': '0x035d13210792f349556bd3708fc23c2ed51d56d4',
#   'symbol': 'MAPLE',
#   'txCount': '71'},
#  {'id': '0x035df12e0f3ac6671126525f1015e47d79dfeddf',
#   'symbol': '0xMR',
#   'txCount': '3459'},
#  {'id': '0x036058294cef4785fcb5b8ceac6dc8af69319d6d',
#   'symbol': 'DefiDoggy',
#   'txCount': '6'},
#  {'id': '0x0362eb0cbb99175a8148c57b87f0d11b5af74714',
#   'symbol': 'RARI',
#   'txCount': '3'},
#  {'id': '0x0369d05ad1812253371889b18d5f2496935fa1f8',
#   'symbol': 'QSP',
#   'txCount': '11'},
#  {'id': '0x036e5f38f29401472f65514ab88d5957bd99ba99',
#   'symbol': 'BLUE',
#   'txCount': '5'},
#  {'id': '0x036ea7048a4c1f28b299b9dd9e3c9fe9022e2a2a',
#   'symbol': 'SHIBAKITA',
#   'txCount': '54'},
#  {'id': '0x03701347a7920e585d3c1437b6464101ea00afb2',
#   'symbol': 'TKF',
#   'txCount': '14'},
#  {'id': '0x0374a144f799bc64ec00c03dbb9065ad19e84c4e',
#   'symbol': 'DMN',
#   'txCount': '30'},
#  {'id': '0x0377275a82d619ce40e73a46eedf4a94497a45e1',
#   'symbol': 'BOOM',
#   'txCount': '5'},
#  {'id': '0x0379d3ef4a5baadb809781ea845281952e91b8f1',
#   'symbol': 'KAFIR',
#   'txCount': '22'},
#  {'id': '0x037a54aab062628c9bbae1fdb1583c195585fe41',
#   'symbol': 'LCX',
#   'txCount': '54633'},
#  {'id': '0x037a7658539db2a3d44c0b66de29a33cd5c9e457',
#   'symbol': 'XCAD',
#   'txCount': '39'},
#  {'id': '0x037ccca2a09acf981364ca01c3e9785dd347fc5c',
#   'symbol': 'HYPER',
#   'txCount': '25'},
#  {'id': '0x037e13e7578c2bd6222fc019a9b9653db007c78b',
#   'symbol': 'UNIBLOCK',
#   'txCount': '14'},
#  {'id': '0x038046037213748c71e11a6919a822e5d5448038',
#   'symbol': 'ACXT',
#   'txCount': '4'},
#  {'id': '0x03829f5675f3b51d0f8c2a74417a757625acf22f',
#   'symbol': 'YFIB',
#   'txCount': '4314'},
#  {'id': '0x0384b905c987c64407ce36ce409707882bf7bdef',
#   'symbol': 'UNN',
#   'txCount': '28'},
#  {'id': '0x038500ff8e3829efe09bbc91abdc1e10104e92cd',
#   'symbol': 'DTA',
#   'txCount': '4'},
#  {'id': '0x038539c8966d0981df9bacaade7551453e185c9f',
#   'symbol': 'CRONJE',
#   'txCount': '48'},
#  {'id': '0x038590663fa652985059ce30826de28095cd18a9',
#   'symbol': 'ALN',
#   'txCount': '2'},
#  {'id': '0x03882d034804740e3208911bc00663e07e023336',
#   'symbol': 'CADANCE',
#   'txCount': '3'},
#  {'id': '0x038842613c484e868c5c296c333a5aca336453d7',
#   'symbol': 'EPIC',
#   'txCount': '20'},
#  {'id': '0x038a68ff68c393373ec894015816e33ad41bd564',
#   'symbol': 'GLCH',
#   'txCount': '43129'},
#  {'id': '0x038e7d67ca6f471b518abca47bfc966197028f69',
#   'symbol': 'DELTA',
#   'txCount': '61'},
#  {'id': '0x038ee3f6534fcb5a6b876b346efb18a797bca3ed',
#   'symbol': 'CORP',
#   'txCount': '20'},
#  {'id': '0x0390046efdac8268ddb83c58e021ff3c910ff31e',
#   'symbol': 'CHR',
#   'txCount': '4'},
#  {'id': '0x0391386dd6656fe5275a7641ecb789e856cf3998',
#   'symbol': 'EVM',
#   'txCount': '115'},
#  {'id': '0x03915cfbbda862ee6a97d3dd43e89d841cf3f6f7',
#   'symbol': 'pneumonoultramicroscopicsilicovolcanoconiosis',
#   'txCount': '16'},
#  {'id': '0x0391d2021f89dc339f60fff84546ea23e337750f',
#   'symbol': 'BOND',
#   'txCount': '46621'},
#  {'id': '0x0393774a6016069c2884b4e592b0104d3a185ba7',
#   'symbol': 'CORE20',
#   'txCount': '7'},
#  {'id': '0x03942cc7f5b10349d0434044b3ab7a1d28961555',
#   'symbol': 'NEB',
#   'txCount': '7'},
#  {'id': '0x0394635c930716a7a5c0da1da5ed8a0b12305cff',
#   'symbol': 'BME',
#   'txCount': '63'},
#  {'id': '0x0399a329c9c6c0d24c645a1d50b409cf406b8e04',
#   'symbol': 'XENU',
#   'txCount': '4'},
#  {'id': '0x039aa25407d0ce00e87afba994e279606e16922c',
#   'symbol': 'GDEFI',
#   'txCount': '13'},
#  {'id': '0x039b4881b6ef3fdb4da50970ac1ecf8e5d38bbbd',
#   'symbol': 'DLT',
#   'txCount': '14'},
#  {'id': '0x039b9077ffd0bab521c600995e304f8233c7a250',
#   'symbol': 'FNC',
#   'txCount': '3'},
#  {'id': '0x039fe51fb2c5d0e14fb1e03aa026207033d66f84',
#   'symbol': 'YCORE',
#   'txCount': '17'},
#  {'id': '0x03a36bf5bf2ba10420f46aa198a252806a632d7e',
#   'symbol': 'CC',
#   'txCount': '1'},
#  {'id': '0x03a5c5f12bd0bbae973215b1c184ff3ce9942cfc',
#   'symbol': 'YFIB',
#   'txCount': '7'},
#  {'id': '0x03a5d1d4c764decf50ae12decbed8a51a421faa0',
#   'symbol': 'CAPT',
#   'txCount': '1777'},
#  {'id': '0x03a6bdbfd23839ceb57454e2ea4db07fb03543f0',
#   'symbol': 'MINA',
#   'txCount': '60'},
#  {'id': '0x03aa2ba75a5e497e4c3532ef6f60264c6199bcee',
#   'symbol': 'UOS',
#   'txCount': '20'},
#  {'id': '0x03ab458634910aad20ef5f1c8ee96f1d6ac54919',
#   'symbol': 'RAI',
#   'txCount': '26865'},
#  {'id': '0x03ac6ea89607d372675187cff3acf392f329d76f',
#   'symbol': 'FFT',
#   'txCount': '9'},
#  {'id': '0x03aca1181ade0509fd3e7175e5895a2fba90ceea',
#   'symbol': 'UNV',
#   'txCount': '286'},
#  {'id': '0x03af731935d11f1d97b33f6f2bbf516ce0834c41',
#   'symbol': 'PIGF',
#   'txCount': '20'},
#  {'id': '0x03b1592e06c167dce7fb757e3af67b570d019e77',
#   'symbol': 'GDOGE',
#   'txCount': '15'},
#  {'id': '0x03b3bcfbec8057d31fe90009d975e849aadc100a',
#   'symbol': 'STEXR',
#   'txCount': '2'},
#  {'id': '0x03bb9bbf0423e44370e88ec5fc31eecf4e2b4ac2',
#   'symbol': 'STV',
#   'txCount': '8'},
#  {'id': '0x03bbeab8d41fbac2477b417b5df7cbc7d939c44a',
#   'symbol': 'RIN',
#   'txCount': '41'},
#  {'id': '0x03be9d7bb2aaaa0a310e97e7ad64b2df27d27cea',
#   'symbol': 'YGKYL',
#   'txCount': '4'},
#  {'id': '0x03c20fa7763bc616bfd1097d78cee8386bdf94d1',
#   'symbol': 'YCORE',
#   'txCount': '11'},
#  {'id': '0x03c22871551bfdde011901f3b97d677f0f779c4d',
#   'symbol': 'DANDY',
#   'txCount': '16'},
#  {'id': '0x03c2b42def9e9b40fccebb9a94764bc1bcf162ba',
#   'symbol': 'TSLAD',
#   'txCount': '2'},
#  {'id': '0x03c2f1b1ba5c5a6cf6d0af816a721a5827171704',
#   'symbol': 'PF',
#   'txCount': '32'},
#  {'id': '0x03c50991829f6920a12fac8fe79d934cc544ee99',
#   'symbol': 'DESIRE',
#   'txCount': '19'},
#  {'id': '0x03c866291f072471a781e701fbc9ebd2f79260df',
#   'symbol': 'YFLF',
#   'txCount': '606'},
#  {'id': '0x03c9fa84b067d17c2e03108c98f7854295f5421c',
#   'symbol': 'POOLZ',
#   'txCount': '15'},
#  {'id': '0x03cbfd14f07824f1376958dc4ad7c97e140d9ae2',
#   'symbol': 'RCS',
#   'txCount': '6'},
#  {'id': '0x03d3befe3a39989ccbe64c71847dc3241070180b',
# ...
#   'symbol': 'POLX',
#   'txCount': '6'},
#  {'id': '0x06576eb3b212d605b797dc15523d9dc9f4f66db4',
#   'symbol': 'TCP',
#   'txCount': '1579'},
#  {'id': '0x06582d6b04f4ca17fd65ffe7dcae95f66c197aa2',
#   'symbol': 'CHADS',
#   'txCount': '4'},
#  {'id': '0x065937ab1e23b08273f2d1c7ca660a370196769d',
#   'symbol': 'xTRX',
#   'txCount': '1069'},
#  {'id': '0x065ccf8d682995be66e38eaee3c2475f636634ab',
#   'symbol': 'YFIW',
#   'txCount': '3438'},
#  {'id': '0x065ec7d50bf7e9400f469423a23a28e7f2fa6996',
#   'symbol': 'DOT',
#   'txCount': '126'},
#  {'id': '0x0663ed872ac9baa5efad2c29dd73ea5a782179ad',
#   'symbol': 'ISP',
#   'txCount': '12'},
#  {'id': '0x066418ec4b51545cd37fe135fa44c59a19fa7f3e',
#   'symbol': 'amplxxx',
#   'txCount': '4'},
#  {'id': '0x0664b1acc80605977b55c665967c1a2ad0a23fdf',
#   'symbol': 'YFÃ˜',
#   'txCount': '7'},
#  {'id': '0x0665b2a4af27778d45d687def997b2f1e00961a8',
#   'symbol': 'XXYFI',
#   'txCount': '6'},
#  {'id': '0x06677dc4fe12d3ba3c7ccfd0df8cd45e4d4095bf',
#   'symbol': 'WQT',
#   'txCount': '6551'},
#  {'id': '0x066798d9ef0833ccc719076dab77199ecbd178b0',
#   'symbol': 'SAKE',
#   'txCount': '54141'},
#  {'id': '0x0668107899cc3f9038c52980f2d61ec63b3f4685',
#   'symbol': 'CVR',
#   'txCount': '36'},
#  {'id': '0x06684e3d5ce17681b49737502a558c8cc73d7a13',
#   'symbol': 'SOS',
#   'txCount': '408'},
#  {'id': '0x066b97d96ff6e32d872e8caaf0e0ad98b063a43f',
#   'symbol': 'RTK',
#   'txCount': '2'},
#  {'id': '0x066fd9b1764ea70e6e83fd510409546977d53988',
#   'symbol': 'APW',
#   'txCount': '18'},
#  {'id': '0x067085aa0ff4e97a3c61bf06de618e0aae11dbc2',
#   'symbol': 'YPRO',
#   'txCount': '87'},
#  {'id': '0x06715d2e211cf7a6976feb348cb2f6defdf582f8',
#   'symbol': 'MCORE',
#   'txCount': '19'},
#  {'id': '0x0671ee24f9931f4d76c13081c622196b39d81c37',
#   'symbol': 'TCNT',
#   'txCount': '19'},
#  {'id': '0x0672516a17286cd282f8c85459d552ef1f879ab4',
#   'symbol': 'GOGA',
#   'txCount': '9'},
#  {'id': '0x067a3fcc2df29786c21a3ffcdda5f5748e0ce59d',
#   'symbol': 'hallo',
#   'txCount': '10'},
#  {'id': '0x067bc353ac9315955353b52741581eb495005950',
#   'symbol': 'CyberS',
#   'txCount': '45'},
#  {'id': '0x067f323c48ef16960d6e228b2af832e3f52ea3a3',
#   'symbol': 'TDT',
#   'txCount': '71'},
#  {'id': '0x0681a94628636c7963fa7d3ed90098a49a53e6d0',
#   'symbol': 'VAX',
#   'txCount': '16'},
#  {'id': '0x0681f38723d7dd6b3e8d78240fbfd50800786e8e',
#   'symbol': 'CFV3',
#   'txCount': '8'},
#  {'id': '0x06834c17b1a5f7214edafee214bd4a9d3c6bac13',
#   'symbol': 'TBH',
#   'txCount': '16'},
#  {'id': '0x06890d4c65a4cb75be73d7ccb4a8ee7962819e81',
#   'symbol': 'xKNCb',
#   'txCount': '226'},
#  {'id': '0x068fc657cbcc7934d5dd890a3d2621ae7e1d97d6',
#   'symbol': 'SMRT',
#   'txCount': '8'},
#  {'id': '0x069131a539e523f89e760299e5b485632a1f9e4d',
#   'symbol': 'SAFECAT',
#   'txCount': '29'},
#  {'id': '0x06939667ee9c89bd351190fd6d002c042cc197cf',
#   'symbol': 'SWH',
#   'txCount': '70'},
#  {'id': '0x069406c00d4dbd536cadc98d937612456efb9dc8',
#   'symbol': 'KPH3R',
#   'txCount': '137'},
#  {'id': '0x0695d3418f8c9818078fdc958c46466175a796e0',
#   'symbol': 'aSET',
#   'txCount': '7'},
#  {'id': '0x0698dda3c390ff92722f9eed766d8b1727621df9',
#   'symbol': 'ETH2POS',
#   'txCount': '554'},
#  {'id': '0x069c656ad7d380cf2860d06aa4173083a66a3ab0',
#   'symbol': 'PKR',
#   'txCount': '1'},
#  {'id': '0x069cdb196c565177c9e5981f0380214c18a8f7dd',
#   'symbol': 'KP3RW',
#   'txCount': '21'},
#  {'id': '0x069e219ea6d6e1aacda76bdca0fbfb4f6b25fd1c',
#   'symbol': 'PIE',
#   'txCount': '3'},
#  {'id': '0x069e4d10d0cffd778edf19c4acd6836b3cc79342',
#   'symbol': 'SMARTCREDIT',
#   'txCount': '19'},
#  {'id': '0x06a01a4d579479dd5d884ebf61a31727a3d8d442',
#   'symbol': 'Skey',
#   'txCount': '54080'},
#  {'id': '0x06a2c00887866b45de1f8f2263df74e4d8815dfc',
#   'symbol': 'NFT',
#   'txCount': '20'},
#  {'id': '0x06a2fec35dd8a5eb427ff10f645577dc99a7379c',
#   'symbol': 'DORA',
#   'txCount': '41'},
#  {'id': '0x06a332d34a449bdd65354d3772a2716d16b0954e',
#   'symbol': 'GRT',
#   'txCount': '28'},
#  {'id': '0x06a5d00f4d1303f22e189622dedea6ef77c5c65d',
#   'symbol': 'BOMO',
#   'txCount': '38'},
#  {'id': '0x06a648de96de974512d8ffdc2bfaf5238ad2ce8b',
#   'symbol': 'REPUB',
#   'txCount': '64'},
#  {'id': '0x06a68535494bff3fd6d28a1ebe445efb52da0559',
#   'symbol': 'FOX',
#   'txCount': '9'},
#  {'id': '0x06a87f6afec4a739c367bef69eefe383d27106bd',
#   'symbol': 'SCooBi',
#   'txCount': '849'},
#  {'id': '0x06a997fa916bad4981dd2c88695f9552fac6439c',
#   'symbol': 'JFI',
#   'txCount': '455'},
#  {'id': '0x06a9e0d8eb1ae36431d95213396c1ee57120abdd',
#   'symbol': 'LIT',
#   'txCount': '39'},
#  {'id': '0x06ab36b19b8d90001e139ea415b3ca14be68c80a',
#   'symbol': 'KOSH',
#   'txCount': '12'},
#  {'id': '0x06ac03d295f04f21ab862bb40672f79f6e4e802d',
#   'symbol': 'INFI',
#   'txCount': '11'},
#  {'id': '0x06ad9bacc335d658550c3be1fd1a2972f0ed6efd',
#   'symbol': 'BOT',
#   'txCount': '14'},
#  {'id': '0x06af07097c9eeb7fd685c692751d5c66db49c215',
#   'symbol': 'CHAI',
#   'txCount': '769'},
#  {'id': '0x06b179e292f080871825bed5d722162fd96b4c95',
#   'symbol': 'XGG',
#   'txCount': '5042'},
#  {'id': '0x06b3b1d5be213f7992913c7b4395a8cd7afb6262',
#   'symbol': 'SYX',
#   'txCount': '9'},
#  {'id': '0x06b54b59067081ab7687eb74eedcde4fea112962',
#   'symbol': 'GBGT',
#   'txCount': '63'},
#  {'id': '0x06b80a08ab8cb1123c6cde68d07422053556dfc3',
#   'symbol': 'CoreSwap',
#   'txCount': '13'},
#  {'id': '0x06bedb9540d52e8a1ee1718c82ea9bd3d7c1b75c',
#   'symbol': 'YFIG',
#   'txCount': '11'},
#  {'id': '0x06c071e8b440104e6c457a67af25553db71094e0',
#   'symbol': 'Rogue',
#   'txCount': '9'},
#  {'id': '0x06c09b8236a43f52b239aadb19b512297350eb34',
#   'symbol': 'MAO',
#   'txCount': '21'},
#  {'id': '0x06c291b051112077ae18386c3a4d77f44b0ac53c',
#   'symbol': 'UBXT',
#   'txCount': '14'},
#  {'id': '0x06c29bcb39f38d1df63387e9ec55c2320212ca49',
#   'symbol': 'MFI',
#   'txCount': '9'},
#  {'id': '0x06ca63a2ff5ffb4191c32f7829c2b160aba8fe88',
#   'symbol': 'XStake',
#   'txCount': '39'},
#  {'id': '0x06ca771a689d6d5f5e435be2ef1d1ffc6bdb3b4c',
#   'symbol': 'WING',
#   'txCount': '6'},
#  {'id': '0x06cbbd4ef137f330b211a0351e472fb18f4d56d6',
#   'symbol': 'LOVE',
#   'txCount': '4'},
#  {'id': '0x06cc190639748ddb22b7b1f2259a5cb567973d97',
#   'symbol': 'BNEX',
#   'txCount': '2'},
#  {'id': '0x06cf47da7b9bc451c494fa5c74c3ccbe7b322a61',
#   'symbol': 'Laika',
#   'txCount': '76'},
#  {'id': '0x06d05a559027fe3a405cca1d48c4504906fb8a39',
#   'symbol': 'SFP',
#   'txCount': '83'},
#  {'id': '0x06d2e3d77fb2bd6cf343e1ba7f90581b229e7006',
#   'symbol': 'DEEP',
#   'txCount': '9'},
#  {'id': '0x06d40de491aa5946b7e18df96c0bda2a005b0c0f',
#   'symbol': 'MMM',
#   'txCount': '9'},
#  {'id': '0x06d626663d816144aa7e6d51d76ecc8c4e6257b1',
#   'symbol': 'PERP',
#   'txCount': '20'},
#  {'id': '0x06d82f9fb503ca2973dd76a03731645da3f8705f',
#   'symbol': 'ADoKi',
#   'txCount': '615'},
#  {'id': '0x06da58fe3c7016a9c4a48c23d9f13b5fa17e72c3',
#   'symbol': 'WKK',
#   'txCount': '4'},
#  {'id': '0x06db9eec43d16f16b4ea6fad1b9bfd6bf26522bb',
#   'symbol': '$RAPE',
#   'txCount': '3'},
#  {'id': '0x06e0e5cc34bf13c9a89f47b1ea9007ae765785b6',
#   'symbol': 'UFO',
#   'txCount': '29'},
#  {'id': '0x06e0feb0d74106c7ada8497754074d222ec6bcdf',
#   'symbol': 'BTB',
#   'txCount': '188'},
#  {'id': '0x06e17e8212259b706d0c4c5ad435cd4e6f53d3bd',
#   'symbol': 'BTCS',
#   'txCount': '4'},
#  {'id': '0x06e72787a53bfd17ab563f30a35b16d9d2fe42f4',
#   'symbol': 'PRY',
#   'txCount': '100'},
#  {'id': '0x06e74e8a14264b237c7e66e2758dbed592aa55b1',
#   'symbol': 'DEFF',
#   'txCount': '12'},
#  {'id': '0x06ea13f2aef4765d9bd32cde59491803e0b04d24',
#   'symbol': 'K9Finance',
#   'txCount': '36'},
#  {'id': '0x06eaa8d19d2cda6c6dfd4305eb6b67e8f75dcd99',
#   'symbol': 'QNET',
#   'txCount': '4'},
#  {'id': '0x06ec2d284764c510816e2433f5106fa6d7a77fb9',
#   'symbol': 'GE',
#   'txCount': '45'},
#  {'id': '0x06edc88d0799caf9f94c8cc346e39b487c8ec5d9',
#   'symbol': 'AFNT',
#   'txCount': '42'},
#  {'id': '0x06ee5730c9ff0c76f86fffe958a1ce435ce2cc62',
#   'symbol': 'MLQ',
#   'txCount': '25'},
#  {'id': '0x06f201e3b2a6355fe5f287845fb3b42bc0ff6645',
#   'symbol': 'AIOZ',
#   'txCount': '214'},
#  {'id': '0x06f25d48fb1f1f5edc80a7bf9c535d469633799b',
#   'symbol': 'TMPL',
#   'txCount': '9'},
#  {'id': '0x06f3c323f0238c72bf35011071f2b5b7f43a054c',
#   'symbol': 'MASQ',
#   'txCount': '1131'},
#  {'id': '0x06f3ef6005c1e245a697fd4c9458aae95aaf8f29',
#   'symbol': 'Audi',
#   'txCount': '9'},
#  {'id': '0x06f59a767f33eabe3f1a3d3c14997bae8058430c',
#   'symbol': 'USDN',
#   'txCount': '354'},
#  {'id': '0x06f59dd778fd183de777bebda694a92950b6ad47',
#   'symbol': 'FRONT',
#   'txCount': '31'},
#  {'id': '0x06f65b8cfcb13a9fe37d836fe9708da38ecb29b2',
#   'symbol': 'FAME',
#   'txCount': '45'},
#  {'id': '0x06f696fdfafa930563b8ea144a7243b35d131dcd',
#   'symbol': 'UIN',
#   'txCount': '8'},
#  {'id': '0x06f7adc034c46f0d6e7790bbcae89ae2dd97baad',
#   'symbol': 'RUBYST',
#   'txCount': '10'},
#  {'id': '0x06ff1a3b08b63e3b2f98a5124bfc22dc0ae654d3',
#   'symbol': 'KASSIAHOTEL',
#   'txCount': '988'},
#  {'id': '0x0700daaaa350f453620d5dac7665e23934dea8fe',
#   'symbol': 'EXTENS',
#   'txCount': '57'},
#  {'id': '0x0702468449b5d26d43592a0d4f7befebed081061',
#   'symbol': 'BRFI',
#   'txCount': '6'},
#  {'id': '0x0702b0020bc1a5728797a66c8e724b5c89ae9f16',
#   'symbol': 'XYF',
#   'txCount': '18'},
#  {'id': '0x07055b86840c83c9f0875b8658967cc81b50d333',
#   'symbol': 'MEDX',
#   'txCount': '5'},
#  {'id': '0x0707fcd0f4c7f875a2bb744904b4cc008453f046',
#   'symbol': 'SPICE',
#   'txCount': '5'},
#  {'id': '0x07147220fa6c06295464d695e4ec012f6aebc275',
#   'symbol': 'SMN1',
#   'txCount': '509'},
#  {'id': '0x07150e919b4de5fd6a63de1f9384828396f25fdc',
#   'symbol': 'BASE',
#   'txCount': '141214'},
#  {'id': '0x0719766e4b439ce49f20c00600c86d50ce0c607e',
#   'symbol': 'e.xper',
#   'txCount': '11'},
#  {'id': '0x0719caf8fa58d56b9f5e658757a5554aa0f9fb8b',
#   'symbol': 'WOOF',
#   'txCount': '31'},
#  {'id': '0x071a01448360b1d6572863ec29bdf4eef955a8eb',
#   'symbol': 'REDPILL',
#   'txCount': '146'},
#  {'id': '0x071e113c6cbb7834ccbe146e6d8d475a8c201581',
#   'symbol': 'AntiSFI',
#   'txCount': '8'},
#  {'id': '0x071ecb8a06d60b4d9dc53676ae2d0d7514ed4c3c',
#   'symbol': 'wKSA',
#   'txCount': '3437'},
#  {'id': '0x072618734010cbf330077313d6dcee407d66b808',
#   'symbol': 'YCATT',
#   'txCount': '30'},
#  {'id': '0x0727b887bbb920620a891bb8dd7e1492929c12f5',
#   'symbol': 'OKTO',
#   'txCount': '2'},
#  {'id': '0x0729e2431558a317d79f83d28c1139ce05590aac',
#   'symbol': 'YUGE',
#   'txCount': '5'},
#  {'id': '0x072a1ba9fa10dea38ad2f4043a8385fbbf108cb2',
#   'symbol': '$TATR',
#   'txCount': '57'},
#  {'id': '0x072c46f392e729c1f0d92a307c2c6dba06b5d078',
#   'symbol': 'SNOGE',
#   'txCount': '4895'},
#  {'id': '0x072eea99de8ee9c57c6309329725e666043a6a7a',
#   'symbol': 'ADAX',
#   'txCount': '39'},
#  {'id': '0x073106461571376660a0459a6508f0e7fdfc50f2',
#   'symbol': 'YFWG',
#   'txCount': '11'},
#  {'id': '0x0731085b3d3672dff436a2bb90460cf1da8499dd',
#   'symbol': 'AUTO',
#   'txCount': '10'},
#  {'id': '0x07311b31ac26bec0742bfa75bc944eaf15adfae3',
#   'symbol': 'ADOG',
#   'txCount': '19'},
#  {'id': '0x073315b35825769de92ac2642451623b16c382cf',
#   'symbol': 'LIBRA',
#   'txCount': '4'},
#  {'id': '0x0734b447f0df7afcf2e979668b068d6698a10795',
#   'symbol': 'KP3RV2',
#   'txCount': '50'},
#  {'id': '0x073613926309f00be59745527cd550dd37a03002',
#   'symbol': 'ALM',
#   'txCount': '26'},
#  {'id': '0x073663105ff5ac3ad070b9b2c91067fafca07813',
#   'symbol': 'YTI',
#   'txCount': '3'},
#  {'id': '0x073825fb6bbf0d084c6e930c188a3eb92e7945ca',
#   'symbol': 'DOGEF',
#   'txCount': '4'},
#  {'id': '0x073adb81dc123fc6c38d96897aa445e125620d52',
#   'symbol': 'FLEEK',
#   'txCount': '11'},
#  {'id': '0x073af3f70516380654ba7c5812c4ab0255f081bc',
#   'symbol': 'TRUMPWIN',
#   'txCount': '2'},
#  {'id': '0x073db0bb9b2cd247592b7388d36b159a6ad9e5fe',
#   'symbol': 'CHONK',
#   'txCount': '12'},
#  {'id': '0x07417875b0d0f64f6822efcef588208f5a4c83e9',
#   'symbol': 'WF',
#   'txCount': '7'},
#  {'id': '0x07418e00458f0a228cf11ca702e10d8348897b81',
#   'symbol': 'RZX',
#   'txCount': '10'},
#  {'id': '0x074502f44dfdbb6386fc3a30c145be49efacb03b',
#   'symbol': 'DRIFT3R',
#   'txCount': '4'},
#  {'id': '0x0746b8cb6dd33134baf0ead66146f442c098b42e',
#   'symbol': 'HALO',
#   'txCount': '19'},
#  {'id': '0x07472fe96555b092cfc32e28dfb9a0accd29ffd8',
#   'symbol': 'SSP',
#   'txCount': '341'},
#  {'id': '0x07479f4dcc427057381cac10d01211f00fd489aa',
#   'symbol': 'WISE',
#   'txCount': '87'},
#  {'id': '0x074a4e4808a0757889cd433697c9ccec9855fa2b',
#   'symbol': 'EQL',
#   'txCount': '54'},
#  {'id': '0x074b513b348bdc586d953ac8370a1f62d841f404',
#   'symbol': 'SBC',
#   'txCount': '17'},
#  {'id': '0x074bb7fbe3ae5f00e3b2745920574d63ea78cde4',
#   'symbol': 'DTFH',
#   'txCount': '7'},
#  {'id': '0x074d837fd9576247c4ce243e528eaaecfbc42235',
#   'symbol': 'FLAMETIC',
#   'txCount': '512'},
#  {'id': '0x0750b58682ef9606a298054a828d6af2d1e77d37',
#   'symbol': 'TRASHER',
#   'txCount': '3'},
#  {'id': '0x075190c6130ea0a3a7e40802f1d77f4ea8f38fe2',
#   'symbol': 'N0031',
#   'txCount': '3416'},
#  {'id': '0x07535296ef1d80a28b7934df87e7412d71fa60d2',
#   'symbol': 'PST',
#   'txCount': '12'},
#  {'id': '0x07597255910a51509ca469568b048f2597e72504',
#   'symbol': '1UP',
#   'txCount': '26842'},
#  {'id': '0x07597b85ea6a5297ffac4d36ed20b6f961ad6a5f',
#   'symbol': 'yfk',
#   'txCount': '6'},
#  {'id': '0x075a8bfdee4ef858c7ca0ca66fe3b187ed634dcb',
#   'symbol': 'INR',
#   'txCount': '739'},
#  {'id': '0x075b1bb99792c9e1041ba13afef80c91a1e70fb3',
#   'symbol': 'crvRenWSBTC',
#   'txCount': '216'},
#  {'id': '0x075f95eefbe0c5706588142afb3ef0df98b24987',
#   'symbol': 'INFI',
#   'txCount': '11'},
#  {'id': '0x075fbc0a804de702bfda4d8e29834c763ffef1c3',
#   'symbol': 'PIKA',
#   'txCount': '16'},
#  {'id': '0x0760542adf7490a55031729d115240bcf411d8ae',
#   'symbol': 'ANT',
#   'txCount': '19'},
#  {'id': '0x0760fb883e80846dd386b4cb87f4123309c7109b',
#   'symbol': 'ALPHA',
#   'txCount': '122'},
#  {'id': '0x076243e3bdf52de17532acf17c2f266ed8695c10',
#   'symbol': 'KNV',
#   'txCount': '15'},
#  {'id': '0x0763d730262bcb2f6c818272f6290b2cfa55e454',
#   'symbol': 'MILK',
#   'txCount': '161'},
#  {'id': '0x0763fdccf1ae541a5961815c0872a8c5bc6de4d7',
#   'symbol': 'SUKU',
#   'txCount': '9666'},
#  {'id': '0x0764c4477804254a75349ec574bf007289a8e1df',
#   'symbol': '$HANNIBAL',
#   'txCount': '2'},
#  {'id': '0x07653c47dc755f14ff90ad5f4fc18b2929d13815',
#   'symbol': 'PUMP',
#   'txCount': '8'},
#  {'id': '0x0769f6ebd95244c70e502c0cb857169d1ed0670d',
#   'symbol': 'LEGIT',
#   'txCount': '29'},
#  {'id': '0x076c97e1c869072ee22f8c91978c99b4bcb02591',
#   'symbol': 'CBT',
#   'txCount': '222'},
#  {'id': '0x0771a42bbb1957dd35ede2f7fe18f0192feeaad9',
#   'symbol': 'LYXe',
#   'txCount': '6'},
#  {'id': '0x0771f996196a471b14a5855caed6c0c67f032045',
#   'symbol': 'CHILL',
#   'txCount': '37'},
#  {'id': '0x077307ffc27256756177a2a2d745112e3df9b803',
#   'symbol': 'STBS',
#   'txCount': '240'},
#  {'id': '0x07762edc9ec705c3f840d2fe201b8d548fc5e4d2',
#   'symbol': 'Alaska',
#   'txCount': '4'},
#  {'id': '0x07782730be9f2bc82c9c42296ed6754b9c9be18e',
#   'symbol': 'CFX',
#   'txCount': '3'},
#  {'id': '0x07786d229c7b866bdc00ed5cc970e74ddd817c27',
#   'symbol': 'CSPR',
#   'txCount': '78'},
#  {'id': '0x0778cc2e8bbad3d483e82371606d100cc8604522',
#   'symbol': 'LHC',
#   'txCount': '13'},
#  {'id': '0x077c2d83565078488bbe6a30569c4592c4906ca7',
#   'symbol': 'SCFI',
#   'txCount': '4'},
#  {'id': '0x0780afaf113ed4324e343e708a59bb7b89f86e7c',
#   'symbol': 'EGM',
#   'txCount': '159'},
#  {'id': '0x0780fc115efbd12ec1733230079092be33551687',
#   'symbol': 'SLSH',
#   'txCount': '8'},
#  {'id': '0x07872c1d399ba89235ad5ce3c2366350fd1198f2',
#   'symbol': 'BYFI',
#   'txCount': '1497'},
#  {'id': '0x0787441c5e0ee933faf8cd29de6cc79341032aa8',
#   'symbol': 'UFT',
#   'txCount': '41'},
#  {'id': '0x07897897a45c558290302b869d16085884780b67',
#   'symbol': 'HAKKA',
#   'txCount': '5'},
#  {'id': '0x0789dbae94fb18e5789b8e4489bcb7a1adb58622',
#   'symbol': 'FSCC',
#   'txCount': '54'},
#  {'id': '0x078abc908c43e98d257c4bce8c5530e590ef40c3',
#   'symbol': 'WBET',
#   'txCount': '61'},
#  {'id': '0x078b728243b975d1a284666c30b30530a8c087fe',
#   'symbol': 'ycrvSNOW',
#   'txCount': '1343'},
#  {'id': '0x078dbeab281befe80fff6ea151355ef5c9dfc1dc',
#   'symbol': 'P2PL',
#   'txCount': '40'},
#  {'id': '0x07952f9ba1708a0ba82ddee602e465514d6696de',
#   'symbol': 'APE',
#   'txCount': '2'},
#  {'id': '0x07970f40645493f6fa99ed82658fc5b6544bc1e1',
#   'symbol': 'CRY',
#   'txCount': '1'},
#  {'id': '0x07977b31dd8078a877d202d976d37bc1ca95663e',
#   'symbol': 'BURN',
#   'txCount': '10'},
#  {'id': '0x079b4b239032992d7e5e8b0e3f385569cfa8de8b',
#   'symbol': 'QTAAR',
#   'txCount': '12'},
#  ...]

# %%
#token_df_data = token_data['data']['tokens']
token_df = pd.DataFrame(token_list)
token_df = token_df.drop_duplicates(ignore_index = True)
token_df.head()
# Out:
#                                            id symbol txCount
# 0  0x00000000000045166c45af0fc6e4cf31d9e14b9a    BID     907
# 1  0x0000000000004946c0e9f43f4dee607b0ef1fa1c    CHI   61725
# 2  0x000000000000d0151e748d25b766e77efe2a6c83   XDEX    3245
# 3  0x0000000000085d4780b73119b644ae5ecd22b376   TUSD   37134
# 4  0x0000000000095413afc295d19edeb1ad7b71c952    LON   43693

# %%
len(token_df)
# Out:
# 5100

# %%
token_df['txCount'] = token_df['txCount'].astype(int)
token_df.dtypes
# Out:
# id         object
# symbol     object
# txCount     int64
# dtype: object

# %%
token_df.sort_values('txCount', ascending = False)
# Out:
#                                               id   symbol  txCount
# 4063  0x1f9840a85d5af5bf1d1762f925bdaddc4201f984      UNI   714185
# 4432  0x2260fac5e5542a773aa44fbcfedf7c193bc2c599     WBTC   576712
# 1529  0x0bc529c00c6401aef6d220be8c6ea1667f6ad93e      YFI   280276
# 3725  0x1ceb5cb57c4d4e2b2433641b95dd330a33185a44     KP3R   198559
# 1427  0x0ae055097c6d159879521c384f1d2123d1f195e6    STAKE   147373
# ...                                          ...      ...      ...
# 5053  0x2754cb68b3e4282ac620cc87361858dbbec1d57e  SNLðŸš€        0
# 3681  0x1ca9b77016630e71035897d2a6e202644c23566b     RAGE        0
# 4472  0x22ad3fab750fb53118e4d6aa85343056a736394b    APEv2        0
# 2172  0x10fc1af52c117bc29d56eb7c2187addb37cd4201     FLIP        0
# 3778  0x1d47f2a94d5a6d59d2a37ef47ca7f71b661654c8     MINK        0
#
# [5100 rows x 3 columns]

# %%
max_token = token_df['txCount'].max()

# %%
token_df[token_df['txCount'] == max_token]
# Out:
#                                               id symbol  txCount
# 4063  0x1f9840a85d5af5bf1d1762f925bdaddc4201f984    UNI   714185

# %%
transaction_query = """query{
  transactions (first: 100 skip:0) {
    id,
    timestamp,
    blockNumber,
    mints {id,pair
      {token0{
        symbol,
        totalLiquidity}, 
        token1{
          symbol,
          totalLiquidity}, 
        liquidityProviderCount}},
    burns {id,pair
      {token0{
        symbol,
        totalLiquidity},
        token1{
          symbol,
          totalLiquidity},
          liquidityProviderCount}},
    swaps {id,pair
    {token0{
      symbol,
      totalLiquidity},
      token1{
        symbol,
        totalLiquidity},
        liquidityProviderCount}},
      }
}"""

# %%
transaction_req = requests.post(uniswap_url, json={'query': transaction_query})
print(transaction_req.status_code)
# Out:
# 200

# %%
transaction_req.text
# Out:
# '{"data":{"transactions":[{"blockNumber":"11666935","burns":[],"id":"0x0000000605df365a8aac7506d995391b760f238366f1526f158912629d855051","mints":[],"swaps":[{"id":"0x0000000605df365a8aac7506d995391b760f238366f1526f158912629d855051-0","pair":{"liquidityProviderCount":"0","token0":{"symbol":"LGCY","totalLiquidity":"372117587.286137083651668861"},"token1":{"symbol":"WETH","totalLiquidity":"898445.948240992798101366"}}}],"timestamp":"1610809598"},{"blockNumber":"11144650","burns":[],"id":"0x0000014be80cf0233ac4fefc02bd9dee376e197ca98ed4af6e6f9fe2cd5b428c","mints":[],"swaps":[{"id":"0x0000014be80cf0233ac4fefc02bd9dee376e197ca98ed4af6e6f9fe2cd5b428c-0","pair":{"liquidityProviderCount":"0","token0":{"symbol":"WBTC","totalLiquidity":"3372.26484373"},"token1":{"symbol":"WETH","totalLiquidity":"898445.948240992798101366"}}}],"timestamp":"1603881516"},{"blockNumber":"12175219","burns":[],"id":"0x0000022f3ec65cec795729c4e16d7f07581e02d1a6fc31ee39e59e36ad86c4b7","mints":[],"swaps":[{"id":"0x0000022f3ec65cec795729c4e16d7f07581e02d1a6fc31ee39e59e36ad86c4b7-0","pair":{"liquidityProviderCount":"0","token0":{"symbol":"GLQ","totalLiquidity":"27366451.409040398471374506"},"token1":{"symbol":"WETH","totalLiquidity":"898445.948240992798101366"}}}],"timestamp":"1617566450"},{"blockNumber":"11810947","burns":[],"id":"0x000002c42681f10a0e971f5ff4f4f427d00777d2258eb750b8dad4c15971a029","mints":[],"swaps":[{"id":"0x000002c42681f10a0e971f5ff4f4f427d00777d2258eb750b8dad4c15971a029-0","pair":{"liquidityProviderCount":"0","token0":{"symbol":"CTASK","totalLiquidity":"547888.771108604573246139"},"token1":{"symbol":"WETH","totalLiquidity":"898445.948240992798101366"}}}],"timestamp":"1612722749"},{"blockNumber":"11882563","burns":[],"id":"0x000003f4bc10887bcfe732cba43220595a3c097ddcb4813f955748cabcc5b82e","mints":[],"swaps":[{"id":"0x000003f4bc10887bcfe732cba43220595a3c097ddcb4813f955748cabcc5b82e-0","pair":{"liquidityProviderCount":"0","token0":{"symbol":"WETH","totalLiquidity":"898445.948240992798101366"},"token1":{"symbol":"XED","totalLiquidity":"2445135.442248003128726982"}}}],"timestamp":"1613674469"},{"blockNumber":"12252512","burns":[],"id":"0x00000404c2d2e22336cc1059ce4d6c5f2272a5f7dffbde09546042e5f4f92d9c","mints":[],"swaps":[{"id":"0x00000404c2d2e22336cc1059ce4d6c5f2272a5f7dffbde09546042e5f4f92d9c-0","pair":{"liquidityProviderCount":"0","token0":{"symbol":"EBOX","totalLiquidity":"1536250.150591019539128191"},"token1":{"symbol":"WETH","totalLiquidity":"898445.948240992798101366"}}},{"id":"0x00000404c2d2e22336cc1059ce4d6c5f2272a5f7dffbde09546042e5f4f92d9c-1","pair":{"liquidityProviderCount":"0","token0":{"symbol":"SHIB","totalLiquidity":"475554055377.150282272773840304"},"token1":{"symbol":"WETH","totalLiquidity":"898445.948240992798101366"}}}],"timestamp":"1618594719"},{"blockNumber":"11681727","burns":[],"id":"0x000004d4b05a966f7df82e2c3ddf9faa9fc3e8c37cdb5c9a7d77bd0e43c97c15","mints":[],"swaps":[{"id":"0x000004d4b05a966f7df82e2c3ddf9faa9fc3e8c37cdb5c9a7d77bd0e43c97c15-0","pair":{"liquidityProviderCount":"0","token0":{"symbol":"STAKE","totalLiquidity":"306357.411159493869481508"},"token1":{"symbol":"WETH","totalLiquidity":"898445.948240992798101366"}}}],"timestamp":"1611006193"},{"blockNumber":"10636279","burns":[],"id":"0x000004f2ae5c45867e363aac03d7c9c5e4f482a365b8a03fb4af46f6037a8c99","mints":[],"swaps":[{"id":"0x000004f2ae5c45867e363aac03d7c9c5e4f482a365b8a03fb4af46f6037a8c99-0","pair":{"liquidityProviderCount":"0","token0":{"symbol":"WETH","totalLiquidity":"898445.948240992798101366"},"token1":{"symbol":"USDT","totalLiquidity":"395172373.535735"}}},{"id":"0x000004f2ae5c45867e363aac03d7c9c5e4f482a365b8a03fb4af46f6037a8c99-1","pair":{"liquidityProviderCount":"0","token0":{"symbol":"1UP","totalLiquidity":"971180.262444343063869565"},"token1":{"symbol":"WETH","totalLiquidity":"898445.948240992798101366"}}}],"timestamp":"1597117264"},{"blockNumber":"11520428","burns":[],"id":"0x00000554f8f0d486ccbb5ff69c882d448ea0ef95931ce5e0616b0d34178399bc","mints": ...

# %%
transaction_data = json.loads(transaction_req.text)
transaction_df_data = transaction_data['data']['transactions']
transaction_df = pd.DataFrame(transaction_df_data)
transaction_df.head()
# Out:
#   blockNumber burns                                                 id mints  \
# 0    11666935    []  0x0000000605df365a8aac7506d995391b760f238366f1...    []
# 1    11144650    []  0x0000014be80cf0233ac4fefc02bd9dee376e197ca98e...    []
# 2    12175219    []  0x0000022f3ec65cec795729c4e16d7f07581e02d1a6fc...    []
# 3    11810947    []  0x000002c42681f10a0e971f5ff4f4f427d00777d2258e...    []
# 4    11882563    []  0x000003f4bc10887bcfe732cba43220595a3c097ddcb4...    []
#
#                                                swaps   timestamp
# 0  [{'id': '0x0000000605df365a8aac7506d995391b760...  1610809598
# 1  [{'id': '0x0000014be80cf0233ac4fefc02bd9dee376...  1603881516
# 2  [{'id': '0x0000022f3ec65cec795729c4e16d7f07581...  1617566450
# 3  [{'id': '0x000002c42681f10a0e971f5ff4f4f427d00...  1612722749
# 4  [{'id': '0x000003f4bc10887bcfe732cba43220595a3...  1613674469

# %%
transaction_df[transaction_df['mints'] != '[]']
# Out:
#    blockNumber burns                                                 id mints  \
# 0     11666935    []  0x0000000605df365a8aac7506d995391b760f238366f1...    []
# 1     11144650    []  0x0000014be80cf0233ac4fefc02bd9dee376e197ca98e...    []
# 2     12175219    []  0x0000022f3ec65cec795729c4e16d7f07581e02d1a6fc...    []
# 3     11810947    []  0x000002c42681f10a0e971f5ff4f4f427d00777d2258e...    []
# 4     11882563    []  0x000003f4bc10887bcfe732cba43220595a3c097ddcb4...    []
# ..         ...   ...                                                ...   ...
# 95    11813662    []  0x00002739799542ae1a832a2d8a10f3bc1fcef6c2b705...    []
# 96    10790486    []  0x0000275a2b0d03f19da89820936f9150da966c6fd33a...    []
# 97    12021498    []  0x000027cfde545b419f34ccad26079d8b4623bc78ccb6...    []
# 98    11107526    []  0x00002892cb2507bf58a9cbe2d90e9d7f5526cd5f7eac...    []
# 99    11286184    []  0x0000292427f09c85e9fa8de9e9bc3a9c9c5079ce8df9...    []
#
#                                                 swaps   timestamp
# 0   [{'id': '0x0000000605df365a8aac7506d995391b760...  1610809598
# 1   [{'id': '0x0000014be80cf0233ac4fefc02bd9dee376...  1603881516
# 2   [{'id': '0x0000022f3ec65cec795729c4e16d7f07581...  1617566450
# 3   [{'id': '0x000002c42681f10a0e971f5ff4f4f427d00...  1612722749
# 4   [{'id': '0x000003f4bc10887bcfe732cba43220595a3...  1613674469
# ..                                                ...         ...
# 95  [{'id': '0x00002739799542ae1a832a2d8a10f3bc1fc...  1612758835
# 96  [{'id': '0x0000275a2b0d03f19da89820936f9150da9...  1599164993
# 97  [{'id': '0x000027cfde545b419f34ccad26079d8b462...  1615522389
# 98  [{'id': '0x00002892cb2507bf58a9cbe2d90e9d7f552...  1603389550
# 99  [{'id': '0x0000292427f09c85e9fa8de9e9bc3a9c9c5...  1605759272
#
# [100 rows x 6 columns]

# %% [markdown]
# # Choose a specific pair

# %%
pair_query = """query{
  pairs(where: {id: "0x8ae720a71622e824f576b4a8c03031066548a3b1"}) {
    token0{name},
    token1{name},
    reserve0,
    reserve1
  }
}"""

# %%
pair_req = requests.post(uniswap_url, json={'query': pair_query})
print(pair_req.status_code)
pair_data = json.loads(pair_req.text)
pair_df_data = pair_data['data']['pairs']
pair_df = pd.DataFrame(pair_df_data)
pair_df.head()
# Out:
# 200
#                      reserve0                 reserve1  \
# 0  9535887.925700367745284385  8389.256613656152910473
#
#                          token0                     token1
# 0  {'name': 'Rai Reflex Index'}  {'name': 'Wrapped Ether'}

# %%
# get initial starting reserves
start_query = """query{
  pairHourDatas (orderBy: hourStartUnix, orderDirection: asc,where: {pair: "0x8ae720a71622e824f576b4a8c03031066548a3b1"}){
    reserve0,
    reserve1,
    pair{token0{name},token1{name}},
    hourStartUnix
  }
}
"""
start_req = requests.post(uniswap_url, json={'query': start_query})
print(start_req.status_code)
start_data = json.loads(start_req.text)
start_df_data = start_data['data']['pairHourDatas']
start_df = pd.DataFrame(start_df_data)
start_df.head()
# Out:
# 200
#    hourStartUnix                                               pair  \
# 0     1613228400  {'token0': {'name': 'Rai Reflex Index'}, 'toke...
# 1     1613232000  {'token0': {'name': 'Rai Reflex Index'}, 'toke...
# 2     1613235600  {'token0': {'name': 'Rai Reflex Index'}, 'toke...
# 3     1613239200  {'token0': {'name': 'Rai Reflex Index'}, 'toke...
# 4     1613264400  {'token0': {'name': 'Rai Reflex Index'}, 'toke...
#
#                  reserve0              reserve1
# 0  328.881972729023859448  3.407384615422587372
# 1  348.881972729023859447  3.217394019605566802
# 2  398.881972729023859447  2.815151152599926087
# 3  456.965832935590048794  2.458261253301938472
# 4   437.45015753017748898  2.568261253301938472

# %%
# get transaction data 
mint_query = """query{
  mints(orderBy: timestamp, orderDirection: asc, where: {pair: "0x8ae720a71622e824f576b4a8c03031066548a3b1"}){
    timestamp,
    amount0,
    amount1
  }
}"""

burn_query = """query{
  burns(orderBy: timestamp, orderDirection: asc, where: {pair: "0x8ae720a71622e824f576b4a8c03031066548a3b1"}){
    timestamp,
    amount0,
    amount1
  }
}"""

swap_query = """query{
  swaps(orderBy: timestamp, orderDirection: asc, where: {pair: "0x8ae720a71622e824f576b4a8c03031066548a3b1"}){
    timestamp,
    amount0In,
    amount1In
    amount0Out,
    amount1Out
  }
}"""

# %%
# queries for mints, burns, and swaps
mint_list = []
burn_list = []
swap_list = []

for i in tqdm(range(0, 1000, 100)):
    mint_query = """query{
      mints(first:100, skip: %d, orderBy: timestamp, orderDirection: asc, where: {pair: "0x8ae720a71622e824f576b4a8c03031066548a3b1"}){
        timestamp,
        amount0,
        amount1
      }
    }""" % (i)

    burn_query = """query{
      burns(first: 100, skip: %d, orderBy: timestamp, orderDirection: asc, where: {pair: "0x8ae720a71622e824f576b4a8c03031066548a3b1"}){
        timestamp,
        amount0,
        amount1
      }
    }""" % (i)

    swap_query = """query{
      swaps(first:100, skip: %d, orderBy: timestamp, orderDirection: asc, where: {pair: "0x8ae720a71622e824f576b4a8c03031066548a3b1"}){
        timestamp,
        amount0In,
        amount1In
        amount0Out,
        amount1Out
      }
    }""" % (i)
    mint_req = requests.post(uniswap_url, json={'query': mint_query})
    burn_req = requests.post(uniswap_url, json={'query': burn_query})
    swap_req = requests.post(uniswap_url, json={'query': swap_query})
    mint_data = json.loads(mint_req.text)
    burn_data = json.loads(burn_req.text)
    swap_data = json.loads(swap_req.text)
    mint_list += mint_data['data']['mints']
    burn_list += burn_data['data']['burns']
    swap_list += swap_data['data']['swaps']

mint_df = pd.DataFrame(mint_list)
burn_df = pd.DataFrame(burn_list)
swap_df = pd.DataFrame(swap_list)
mint_df = mint_df.drop_duplicates()
burn_df = burn_df.drop_duplicates()
swap_df = swap_df.drop_duplicates()
# Out:
# 100%|██████████| 10/10 [00:05<00:00,  1.69it/s]

# %%
initial_state = (pd.DataFrame(start_df.iloc[0]).T)
initial_state = initial_state[['hourStartUnix', 'reserve0', 'reserve1']]
initial_state.rename({'hourStartUnix': 'timestamp', 'reserve0': 'amount0', 'reserve1': 'amount1'}, axis = 1, inplace = True)
initial_state['timestamp'] = pd.to_datetime(initial_state['timestamp'], unit = 's')
initial_state = initial_state.astype({'amount0': float, 'amount1': float})
initial_state
# Out:
#             timestamp                   amount0                 amount1
# 0 2021-02-13 15:00:00  328.88197272902385748239  3.40738461542258752601

# %%
# cleaning mints, burns, and swaps
mint_df = mint_df.astype({'amount0': float, 'amount1': float})
burn_df = burn_df.astype({'amount0': float, 'amount1': float})
swap_df = swap_df.astype({'amount0In': float, 'amount0Out': float, 'amount1In': float, 'amount1Out': float})
mint_df['timestamp'] = pd.to_datetime(mint_df['timestamp'], unit = 's')
burn_df['timestamp'] = pd.to_datetime(burn_df['timestamp'], unit = 's')
swap_df['timestamp'] = pd.to_datetime(swap_df['timestamp'], unit = 's')
burn_df['amount0'] = -1 * burn_df['amount0']
burn_df['amount1'] = -1 * burn_df['amount1']
mint_df.head()
# Out:
#                        amount0                   amount1           timestamp
# 0     800.00000000000000000000    1.39272644036048509619 2021-02-13 15:35:26
# 1     400.00000000000000000000    0.70891403154698950928 2021-02-15 23:21:02
# 2    2737.64874597703101244406    5.00000000000000000000 2021-02-17 01:19:34
# 3  196607.35125402297126129270  350.40852552209679515727 2021-02-17 01:37:27
# 4    1536.91416698432271914498    3.01511418444561085650 2021-02-17 01:56:15

# %%
burn_df.head()
# Out:
#                      amount0                  amount1           timestamp
# 0 -3146.49391029822209020494  -6.72345175651250226423 2021-02-17 02:33:33
# 1  -111.91626309448908216382  -0.19307502511385032928 2021-02-17 03:24:49
# 2 -1961.69673590496995529975  -3.94149255530318187724 2021-02-17 03:59:44
# 3 -6917.77578859275763534242 -14.03929543630983545199 2021-02-17 04:04:28
# 4  -702.00471479365660343319  -1.26651893121047431912 2021-02-17 16:02:21

# %%
swap_df.head()
# Out:
#    amount0In                amount0Out               amount1In  amount1Out  \
# 0        0.0  100.19304745914647014615  0.20000000000000001110         0.0
# 1        0.0  166.81778649541183767724  0.50000000000000000000         0.0
# 2        0.0   46.36656941697624034759  0.20000000000000001110         0.0
# 3        0.0   56.15685386376809873354  0.29999999999999998890         0.0
# 4        0.0   23.47544211188203533425  0.14999999999999999445         0.0
#
#             timestamp
# 0 2021-02-13 15:37:05
# 1 2021-02-13 15:38:03
# 2 2021-02-13 15:39:08
# 3 2021-02-13 15:39:52
# 4 2021-02-13 15:40:42

# %%
# prepare to merge mints, burns, and swaps
mint_df['event'] = 'mint'
burn_df['event'] = 'burn'
swap_df['event'] = ['ethPurchase' if i > 0 else 'tokenPurchase' for i in swap_df['amount0Out']]
swap_df.head(10)
# Out:
#                  amount0In                amount0Out               amount1In  \
# 0   0.00000000000000000000  100.19304745914647014615  0.20000000000000001110
# 1   0.00000000000000000000  166.81778649541183767724  0.50000000000000000000
# 2   0.00000000000000000000   46.36656941697624034759  0.20000000000000001110
# 3   0.00000000000000000000   56.15685386376809873354  0.29999999999999998890
# 4   0.00000000000000000000   23.47544211188203533425  0.14999999999999999445
# 5   0.00000000000000000000  108.50240952697689067463  1.00000000000000000000
# 6   0.00000000000000000000   85.21751517637174799802  1.50000000000000000000
# 7  50.41854932041070469495    0.00000000000000000000  0.00000000000000000000
# 8  50.19304745914646304072    0.00000000000000000000  0.00000000000000000000
# 9  55.00000000000000000000    0.00000000000000000000  0.00000000000000000000
#
#                amount1Out           timestamp          event
# 0  0.00000000000000000000 2021-02-13 15:37:05    ethPurchase
# 1  0.00000000000000000000 2021-02-13 15:38:03    ethPurchase
# 2  0.00000000000000000000 2021-02-13 15:39:08    ethPurchase
# 3  0.00000000000000000000 2021-02-13 15:39:52    ethPurchase
# 4  0.00000000000000000000 2021-02-13 15:40:42    ethPurchase
# 5  0.00000000000000000000 2021-02-13 15:40:45    ethPurchase
# 6  0.00000000000000000000 2021-02-13 15:42:06    ethPurchase
# 7  1.00000000000000000000 2021-02-13 15:42:27  tokenPurchase
# 8  0.67674612043509174697 2021-02-13 15:43:45  tokenPurchase
# 9  0.53032690466032572640 2021-02-13 15:50:35  tokenPurchase

# %%
swap_df['amount0'] = [-1 * i[1]['amount0In'] if i[1]['amount0In'] > 0 else i[1]['amount0Out'] for i in swap_df.iterrows()]
swap_df['amount1'] = [-1 * i[1]['amount1In'] if i[1]['amount1In'] > 0 else i[1]['amount1Out'] for i in swap_df.iterrows()]
swap_df.head(10)
# Out:
#                  amount0In                amount0Out               amount1In  \
# 0   0.00000000000000000000  100.19304745914647014615  0.20000000000000001110
# 1   0.00000000000000000000  166.81778649541183767724  0.50000000000000000000
# 2   0.00000000000000000000   46.36656941697624034759  0.20000000000000001110
# 3   0.00000000000000000000   56.15685386376809873354  0.29999999999999998890
# 4   0.00000000000000000000   23.47544211188203533425  0.14999999999999999445
# 5   0.00000000000000000000  108.50240952697689067463  1.00000000000000000000
# 6   0.00000000000000000000   85.21751517637174799802  1.50000000000000000000
# 7  50.41854932041070469495    0.00000000000000000000  0.00000000000000000000
# 8  50.19304745914646304072    0.00000000000000000000  0.00000000000000000000
# 9  55.00000000000000000000    0.00000000000000000000  0.00000000000000000000
#
#                amount1Out           timestamp          event  \
# 0  0.00000000000000000000 2021-02-13 15:37:05    ethPurchase
# 1  0.00000000000000000000 2021-02-13 15:38:03    ethPurchase
# 2  0.00000000000000000000 2021-02-13 15:39:08    ethPurchase
# 3  0.00000000000000000000 2021-02-13 15:39:52    ethPurchase
# 4  0.00000000000000000000 2021-02-13 15:40:42    ethPurchase
# 5  0.00000000000000000000 2021-02-13 15:40:45    ethPurchase
# 6  0.00000000000000000000 2021-02-13 15:42:06    ethPurchase
# 7  1.00000000000000000000 2021-02-13 15:42:27  tokenPurchase
# 8  0.67674612043509174697 2021-02-13 15:43:45  tokenPurchase
# 9  0.53032690466032572640 2021-02-13 15:50:35  tokenPurchase
#
#                     amount0                 amount1
# 0  100.19304745914647014615 -0.20000000000000001110
# 1  166.81778649541183767724 -0.50000000000000000000
# 2   46.36656941697624034759 -0.20000000000000001110
# 3   56.15685386376809873354 -0.29999999999999998890
# 4   23.47544211188203533425 -0.14999999999999999445
# 5  108.50240952697689067463 -1.00000000000000000000
# 6   85.21751517637174799802 -1.50000000000000000000
# 7  -50.41854932041070469495  1.00000000000000000000
# 8  -50.19304745914646304072  0.67674612043509174697
# 9  -55.00000000000000000000  0.53032690466032572640

# %%
swap_df.drop(columns = ['amount0In', 'amount0Out', 'amount1In', 'amount1Out'], inplace = True)

# %%
# merge mints, buens, and swaps

uniswap_df = pd.concat([initial_state, mint_df, burn_df, swap_df])
uniswap_df = uniswap_df.astype({'amount0': float, 'amount1': float})
uniswap_df = uniswap_df.rename({'amount0': 'token_delta', 'amount1': 'eth_delta'}, axis = 1)
uniswap_df.head()
# Out:
#             timestamp                  token_delta                 eth_delta  \
# 0 2021-02-13 15:00:00     328.88197272902385748239    3.40738461542258752601
# 0 2021-02-13 15:35:26     800.00000000000000000000    1.39272644036048509619
# 1 2021-02-15 23:21:02     400.00000000000000000000    0.70891403154698950928
# 2 2021-02-17 01:19:34    2737.64874597703101244406    5.00000000000000000000
# 3 2021-02-17 01:37:27  196607.35125402297126129270  350.40852552209679515727
#
#   event
# 0   NaN
# 0  mint
# 1  mint
# 2  mint
# 3  mint

# %%
uniswap_df = uniswap_df.sort_values('timestamp')
uniswap_df.reset_index(inplace = True)

# %%
uniswap_df['token_balance'] = uniswap_df['token_delta'].cumsum()
uniswap_df['eth_balance'] = uniswap_df['eth_delta'].cumsum()
uniswap_df.head()
# Out:
#    index           timestamp               token_delta  \
# 0      0 2021-02-13 15:00:00  328.88197272902385748239
# 1      0 2021-02-13 15:35:26  800.00000000000000000000
# 2      0 2021-02-13 15:37:05  100.19304745914647014615
# 3      1 2021-02-13 15:38:03  166.81778649541183767724
# 4      2 2021-02-13 15:39:08   46.36656941697624034759
#
#                 eth_delta        event              token_balance  \
# 0  3.40738461542258752601          NaN   328.88197272902385748239
# 1  1.39272644036048509619         mint  1128.88197272902380063897
# 2 -0.20000000000000001110  ethPurchase  1229.07502018817035605025
# 3 -0.50000000000000000000  ethPurchase  1395.89280668358219372749
# 4 -0.20000000000000001110  ethPurchase  1442.25937610055848381307
#
#               eth_balance
# 0  3.40738461542258752601
# 1  4.80011105578307262221
# 2  4.60011105578307244457
# 3  4.10011105578307244457
# 4  3.90011105578307226693

# %%
uniswap_df.to_csv('../data/clean_graph_data.csv', index = False)
